# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Jawa_DenseNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet169, DenseNet201
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/eursamajor/Aksara/raw/main/Jawa.zip'

zip_path = './Jawa.zip'
extract_path = './'

response = requests.get(url)
with open(zip_path, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

#utk store data yang udah didownload dan extract
dataset_dir = os.path.join(extract_path, 'Jawa')

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 6627 images belonging to 20 classes.
# Found 2214 images belonging to 20 classes.
# Found 2220 images belonging to 20 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'DenseNet169': DenseNet169(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'DenseNet201': DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training DenseNet169...
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 104s 322ms/step - accuracy: 0.3950 - loss: 10.9668 - val_accuracy: 0.7588 - val_loss: 0.7097
# Epoch 2/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 30s 143ms/step - accuracy: 0.7957 - loss: 0.6321 - val_accuracy: 0.8573 - val_loss: 0.4642
# Epoch 3/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.8593 - loss: 0.4142 - val_accuracy: 0.8537 - val_loss: 0.4843
# Epoch 4/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 31s 147ms/step - accuracy: 0.8734 - loss: 0.3599 - val_accuracy: 0.8686 - val_loss: 0.4671
# Epoch 5/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - accuracy: 0.9009 - loss: 0.2843 - val_accuracy: 0.8762 - val_loss: 0.4111
# Epoch 6/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 147ms/step - accuracy: 0.9184 - loss: 0.2202 - val_accuracy: 0.8830 - val_loss: 0.4071
# Epoch 7/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - accuracy: 0.9197 - loss: 0.2222 - val_accuracy: 0.8645 - val_loss: 0.4398
# Epoch 8/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9179 - loss: 0.2590 - val_accuracy: 0.8609 - val_loss: 0.4847
# Epoch 9/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 147ms/step - accuracy: 0.9211 - loss: 0.2298 - val_accuracy: 0.8880 - val_loss: 0.4091
# Epoch 10/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 30s 143ms/step - accuracy: 0.9426 - loss: 0.1705 - val_accuracy: 0.8690 - val_loss: 0.5014
# Epoch 11/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.9154 - loss: 0.2473 - val_accuracy: 0.8695 - val_loss: 0.4682
# Epoch 12/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 45s 163ms/step - accuracy: 0.9472 - loss: 0.1689 - val_accuracy: 0.8695 - val_loss: 0.4880
# Epoch 13/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - accuracy: 0.9068 - loss: 0.3242 - val_accuracy: 0.8704 - val_loss: 0.4564
# Epoch 14/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 34s 163ms/step - accuracy: 0.9353 - loss: 0.1972 - val_accuracy: 0.8717 - val_loss: 0.4488
# Epoch 15/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 31s 148ms/step - accuracy: 0.9254 - loss: 0.2227 - val_accuracy: 0.8650 - val_loss: 0.5556
# Epoch 16/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 40s 144ms/step - accuracy: 0.9467 - loss: 0.1750 - val_accuracy: 0.8830 - val_loss: 0.5119
# Epoch 17/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9453 - loss: 0.1858 - val_accuracy: 0.8848 - val_loss: 0.4545
# Epoch 18/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 45s 163ms/step - accuracy: 0.9437 - loss: 0.1637 - val_accuracy: 0.8799 - val_loss: 0.4896
# Epoch 19/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 31s 146ms/step - accuracy: 0.9481 - loss: 0.1470 - val_accuracy: 0.8767 - val_loss: 0.5622
# Epoch 20/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9386 - loss: 0.1875 - val_accuracy: 0.8749 - val_loss: 0.6182
# Epoch 21/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 35s 165ms/step - accuracy: 0.9481 - loss: 0.1627 - val_accuracy: 0.8722 - val_loss: 0.6630
# Epoch 22/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 40s 162ms/step - accuracy: 0.9583 - loss: 0.1189 - val_accuracy: 0.8699 - val_loss: 0.5957
# Epoch 23/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 34s 164ms/step - accuracy: 0.9483 - loss: 0.1670 - val_accuracy: 0.8699 - val_loss: 0.7273
# Epoch 24/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - accuracy: 0.9410 - loss: 0.2005 - val_accuracy: 0.8573 - val_loss: 0.6368
# Epoch 25/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 45s 163ms/step - accuracy: 0.9437 - loss: 0.1729 - val_accuracy: 0.8631 - val_loss: 0.6653
# Epoch 26/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 37s 147ms/step - accuracy: 0.9427 - loss: 0.1850 - val_accuracy: 0.8708 - val_loss: 0.6207
# Epoch 27/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9583 - loss: 0.1393 - val_accuracy: 0.8699 - val_loss: 0.5936
# Epoch 28/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9643 - loss: 0.1182 - val_accuracy: 0.8880 - val_loss: 0.5820
# Epoch 29/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 30s 144ms/step - accuracy: 0.9714 - loss: 0.0878 - val_accuracy: 0.8839 - val_loss: 0.7209
# Epoch 30/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - accuracy: 0.9608 - loss: 0.1260 - val_accuracy: 0.8817 - val_loss: 0.6926
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 20s 281ms/step - accuracy: 0.9083 - loss: 0.5092
# Training DenseNet201...
# Epoch 1/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 127s 430ms/step - accuracy: 0.4084 - loss: 10.1664 - val_accuracy: 0.8044 - val_loss: 0.6172
# Epoch 2/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 73s 179ms/step - accuracy: 0.7978 - loss: 0.6126 - val_accuracy: 0.8342 - val_loss: 0.5196
# Epoch 3/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.8684 - loss: 0.4021 - val_accuracy: 0.8645 - val_loss: 0.4389
# Epoch 4/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 183ms/step - accuracy: 0.8906 - loss: 0.3164 - val_accuracy: 0.8464 - val_loss: 0.4741
# Epoch 5/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 181ms/step - accuracy: 0.9044 - loss: 0.2818 - val_accuracy: 0.8830 - val_loss: 0.3911
# Epoch 6/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9228 - loss: 0.2173 - val_accuracy: 0.8677 - val_loss: 0.4166
# Epoch 7/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9277 - loss: 0.2056 - val_accuracy: 0.8839 - val_loss: 0.3852
# Epoch 8/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9313 - loss: 0.1959 - val_accuracy: 0.8726 - val_loss: 0.4384
# Epoch 9/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 183ms/step - accuracy: 0.9356 - loss: 0.1887 - val_accuracy: 0.8835 - val_loss: 0.4223
# Epoch 10/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9381 - loss: 0.1924 - val_accuracy: 0.8889 - val_loss: 0.4496
# Epoch 11/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9332 - loss: 0.2020 - val_accuracy: 0.8645 - val_loss: 0.4677
# Epoch 12/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9274 - loss: 0.2227 - val_accuracy: 0.8650 - val_loss: 0.4803
# Epoch 13/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9179 - loss: 0.2351 - val_accuracy: 0.8911 - val_loss: 0.4524
# Epoch 14/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9209 - loss: 0.2397 - val_accuracy: 0.8771 - val_loss: 0.4932
# Epoch 15/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9386 - loss: 0.1777 - val_accuracy: 0.8726 - val_loss: 0.5526
# Epoch 16/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9256 - loss: 0.2241 - val_accuracy: 0.8740 - val_loss: 0.4917
# Epoch 17/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9342 - loss: 0.2019 - val_accuracy: 0.8464 - val_loss: 0.5823
# Epoch 18/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9297 - loss: 0.2076 - val_accuracy: 0.8921 - val_loss: 0.4704
# Epoch 19/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9468 - loss: 0.1542 - val_accuracy: 0.8762 - val_loss: 0.6216
# Epoch 20/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9545 - loss: 0.1348 - val_accuracy: 0.8993 - val_loss: 0.4266
# Epoch 21/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9634 - loss: 0.1134 - val_accuracy: 0.8884 - val_loss: 0.5518
# Epoch 22/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9494 - loss: 0.1551 - val_accuracy: 0.8898 - val_loss: 0.6031
# Epoch 23/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9440 - loss: 0.1749 - val_accuracy: 0.8780 - val_loss: 0.5669
# Epoch 24/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9500 - loss: 0.1674 - val_accuracy: 0.8699 - val_loss: 0.6642
# Epoch 25/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.9558 - loss: 0.1481 - val_accuracy: 0.8835 - val_loss: 0.5258
# Epoch 26/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 40s 192ms/step - accuracy: 0.9584 - loss: 0.1290 - val_accuracy: 0.8830 - val_loss: 0.6233
# Epoch 27/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 40s 185ms/step - accuracy: 0.9520 - loss: 0.1662 - val_accuracy: 0.8862 - val_loss: 0.4939
# Epoch 28/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9595 - loss: 0.1263 - val_accuracy: 0.8803 - val_loss: 0.5361
# Epoch 29/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9556 - loss: 0.1439 - val_accuracy: 0.8803 - val_loss: 0.6964
# Epoch 30/30
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 38s 182ms/step - accuracy: 0.9598 - loss: 0.1269 - val_accuracy: 0.8853 - val_loss: 0.5819
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 22s 315ms/step - accuracy: 0.8889 - loss: 0.5711

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
