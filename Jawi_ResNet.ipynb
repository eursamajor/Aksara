# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Jawi_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2, ResNet101, ResNet101V2, ResNet152, ResNet152V2
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/eursamajor/Aksara/raw/main/Jawi.zip'

zip_path = './Jawi.zip'
extract_path = './'

response = requests.get(url)
with open(zip_path, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

#utk store data yang udah didownload dan extract
dataset_dir = os.path.join(extract_path, 'Jawi')

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 1200 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'ResNet50V2': ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'ResNet101': ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'ResNet101V2': ResNet101V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'ResNet152': ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'ResNet152V2': ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training ResNet50V2...
# Epoch 1/30
# 38/38 [==============================] - 17s 210ms/step - loss: 11.2997 - accuracy: 0.5858 - val_loss: 2.1780 - val_accuracy: 0.8550
# Epoch 2/30
# 38/38 [==============================] - 5s 139ms/step - loss: 0.9224 - accuracy: 0.9175 - val_loss: 1.9315 - val_accuracy: 0.8675
# Epoch 3/30
# 38/38 [==============================] - 5s 138ms/step - loss: 0.3715 - accuracy: 0.9617 - val_loss: 1.1169 - val_accuracy: 0.8950
# Epoch 4/30
# 38/38 [==============================] - 5s 141ms/step - loss: 0.4517 - accuracy: 0.9633 - val_loss: 1.3620 - val_accuracy: 0.8875
# Epoch 5/30
# 38/38 [==============================] - 6s 162ms/step - loss: 0.1714 - accuracy: 0.9767 - val_loss: 2.0819 - val_accuracy: 0.8675
# Epoch 6/30
# 38/38 [==============================] - 6s 149ms/step - loss: 0.4928 - accuracy: 0.9583 - val_loss: 1.4312 - val_accuracy: 0.8825
# Epoch 7/30
# 38/38 [==============================] - 5s 140ms/step - loss: 0.3445 - accuracy: 0.9658 - val_loss: 2.0552 - val_accuracy: 0.8600
# Epoch 8/30
# 38/38 [==============================] - 5s 141ms/step - loss: 0.3358 - accuracy: 0.9675 - val_loss: 1.5604 - val_accuracy: 0.8800
# Epoch 9/30
# 38/38 [==============================] - 5s 142ms/step - loss: 0.2051 - accuracy: 0.9733 - val_loss: 1.6348 - val_accuracy: 0.8800
# Epoch 10/30
# 38/38 [==============================] - 6s 147ms/step - loss: 0.2285 - accuracy: 0.9717 - val_loss: 1.8797 - val_accuracy: 0.8850
# Epoch 11/30
# 38/38 [==============================] - 5s 142ms/step - loss: 0.1988 - accuracy: 0.9792 - val_loss: 1.5650 - val_accuracy: 0.9150
# Epoch 12/30
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1713 - accuracy: 0.9817 - val_loss: 2.3608 - val_accuracy: 0.8825
# Epoch 13/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.3070 - accuracy: 0.9808 - val_loss: 2.4284 - val_accuracy: 0.8750
# Epoch 14/30
# 38/38 [==============================] - 6s 149ms/step - loss: 0.1805 - accuracy: 0.9750 - val_loss: 2.8318 - val_accuracy: 0.8575
# Epoch 15/30
# 38/38 [==============================] - 6s 146ms/step - loss: 0.4374 - accuracy: 0.9750 - val_loss: 1.7314 - val_accuracy: 0.8950
# Epoch 16/30
# 38/38 [==============================] - 5s 142ms/step - loss: 0.3710 - accuracy: 0.9767 - val_loss: 2.3202 - val_accuracy: 0.8775
# Epoch 17/30
# 38/38 [==============================] - 5s 141ms/step - loss: 0.1225 - accuracy: 0.9883 - val_loss: 2.0755 - val_accuracy: 0.9050
# Epoch 18/30
# 38/38 [==============================] - 5s 145ms/step - loss: 0.1260 - accuracy: 0.9867 - val_loss: 2.6931 - val_accuracy: 0.8700
# Epoch 19/30
# 38/38 [==============================] - 5s 140ms/step - loss: 0.3193 - accuracy: 0.9733 - val_loss: 3.0595 - val_accuracy: 0.8900
# Epoch 20/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1341 - accuracy: 0.9842 - val_loss: 2.1768 - val_accuracy: 0.8950
# Epoch 21/30
# 38/38 [==============================] - 5s 141ms/step - loss: 0.1923 - accuracy: 0.9900 - val_loss: 2.8237 - val_accuracy: 0.8950
# Epoch 22/30
# 38/38 [==============================] - 5s 141ms/step - loss: 0.2044 - accuracy: 0.9850 - val_loss: 3.4150 - val_accuracy: 0.8775
# Epoch 23/30
# 38/38 [==============================] - 6s 147ms/step - loss: 0.2460 - accuracy: 0.9817 - val_loss: 2.9960 - val_accuracy: 0.8775
# Epoch 24/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.3553 - accuracy: 0.9767 - val_loss: 1.8884 - val_accuracy: 0.9250
# Epoch 25/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.4500 - accuracy: 0.9800 - val_loss: 2.0656 - val_accuracy: 0.9225
# Epoch 26/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2542 - accuracy: 0.9850 - val_loss: 3.4252 - val_accuracy: 0.8875
# Epoch 27/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.1609 - accuracy: 0.9917 - val_loss: 3.6711 - val_accuracy: 0.9025
# Epoch 28/30
# 38/38 [==============================] - 5s 142ms/step - loss: 0.1414 - accuracy: 0.9900 - val_loss: 3.1451 - val_accuracy: 0.9050
# Epoch 29/30
# 38/38 [==============================] - 5s 144ms/step - loss: 0.2809 - accuracy: 0.9825 - val_loss: 2.8532 - val_accuracy: 0.9100
# Epoch 30/30
# 38/38 [==============================] - 5s 141ms/step - loss: 0.1431 - accuracy: 0.9825 - val_loss: 2.8095 - val_accuracy: 0.9050
# 13/13 [==============================] - 1s 91ms/step - loss: 1.6455 - accuracy: 0.9125
# Training ResNet101...
# Epoch 1/30
# 38/38 [==============================] - 19s 325ms/step - loss: 11.8484 - accuracy: 0.1558 - val_loss: 2.2510 - val_accuracy: 0.4175
# Epoch 2/30
# 38/38 [==============================] - 10s 261ms/step - loss: 1.8485 - accuracy: 0.4625 - val_loss: 1.4038 - val_accuracy: 0.6425
# Epoch 3/30
# 38/38 [==============================] - 10s 263ms/step - loss: 1.4314 - accuracy: 0.5433 - val_loss: 1.2142 - val_accuracy: 0.6800
# Epoch 4/30
# 38/38 [==============================] - 10s 265ms/step - loss: 1.1635 - accuracy: 0.6275 - val_loss: 0.8631 - val_accuracy: 0.7500
# Epoch 5/30
# 38/38 [==============================] - 10s 262ms/step - loss: 1.0419 - accuracy: 0.6692 - val_loss: 0.9727 - val_accuracy: 0.6525
# Epoch 6/30
# 38/38 [==============================] - 10s 260ms/step - loss: 0.8634 - accuracy: 0.7208 - val_loss: 0.7439 - val_accuracy: 0.7575
# Epoch 7/30
# 38/38 [==============================] - 10s 260ms/step - loss: 0.6483 - accuracy: 0.7883 - val_loss: 0.7119 - val_accuracy: 0.7550
# Epoch 8/30
# 38/38 [==============================] - 10s 266ms/step - loss: 0.5916 - accuracy: 0.7950 - val_loss: 0.6350 - val_accuracy: 0.7800
# Epoch 9/30
# 38/38 [==============================] - 10s 258ms/step - loss: 0.5945 - accuracy: 0.8008 - val_loss: 0.6920 - val_accuracy: 0.7675
# Epoch 10/30
# 38/38 [==============================] - 10s 260ms/step - loss: 0.5708 - accuracy: 0.8033 - val_loss: 0.6272 - val_accuracy: 0.7825
# Epoch 11/30
# 38/38 [==============================] - 10s 261ms/step - loss: 0.5319 - accuracy: 0.8358 - val_loss: 0.5660 - val_accuracy: 0.7850
# Epoch 12/30
# 38/38 [==============================] - 10s 261ms/step - loss: 0.4410 - accuracy: 0.8492 - val_loss: 0.6157 - val_accuracy: 0.7825
# Epoch 13/30
# 38/38 [==============================] - 10s 267ms/step - loss: 0.4138 - accuracy: 0.8708 - val_loss: 0.5796 - val_accuracy: 0.7900
# Epoch 14/30
# 38/38 [==============================] - 10s 259ms/step - loss: 0.3616 - accuracy: 0.8750 - val_loss: 0.5888 - val_accuracy: 0.7875
# Epoch 15/30
# 38/38 [==============================] - 10s 262ms/step - loss: 0.3486 - accuracy: 0.8858 - val_loss: 0.5512 - val_accuracy: 0.7925
# Epoch 16/30
# 38/38 [==============================] - 10s 259ms/step - loss: 0.3120 - accuracy: 0.9008 - val_loss: 0.5274 - val_accuracy: 0.8000
# Epoch 17/30
# 38/38 [==============================] - 10s 260ms/step - loss: 0.2740 - accuracy: 0.9100 - val_loss: 0.5454 - val_accuracy: 0.7950
# Epoch 18/30
# 38/38 [==============================] - 10s 266ms/step - loss: 0.2565 - accuracy: 0.9192 - val_loss: 0.5008 - val_accuracy: 0.8175
# Epoch 19/30
# 38/38 [==============================] - 10s 259ms/step - loss: 0.2565 - accuracy: 0.9167 - val_loss: 0.5191 - val_accuracy: 0.8200
# Epoch 20/30
# 38/38 [==============================] - 10s 263ms/step - loss: 0.2083 - accuracy: 0.9225 - val_loss: 0.4655 - val_accuracy: 0.8325
# Epoch 21/30
# 38/38 [==============================] - 10s 261ms/step - loss: 0.1870 - accuracy: 0.9400 - val_loss: 0.4637 - val_accuracy: 0.8375
# Epoch 22/30
# 38/38 [==============================] - 10s 261ms/step - loss: 0.2529 - accuracy: 0.9142 - val_loss: 0.6748 - val_accuracy: 0.7850
# Epoch 23/30
# 38/38 [==============================] - 10s 258ms/step - loss: 0.2517 - accuracy: 0.9167 - val_loss: 0.5027 - val_accuracy: 0.8050
# Epoch 24/30
# 38/38 [==============================] - 10s 258ms/step - loss: 0.2010 - accuracy: 0.9400 - val_loss: 0.5457 - val_accuracy: 0.8075
# Epoch 25/30
# 38/38 [==============================] - 10s 260ms/step - loss: 0.2070 - accuracy: 0.9308 - val_loss: 0.4854 - val_accuracy: 0.8225
# Epoch 26/30
# 38/38 [==============================] - 10s 259ms/step - loss: 0.1933 - accuracy: 0.9383 - val_loss: 0.4603 - val_accuracy: 0.8275
# Epoch 27/30
# 38/38 [==============================] - 10s 260ms/step - loss: 0.2272 - accuracy: 0.9242 - val_loss: 0.5579 - val_accuracy: 0.8225
# Epoch 28/30
# 38/38 [==============================] - 10s 259ms/step - loss: 0.1880 - accuracy: 0.9467 - val_loss: 0.5040 - val_accuracy: 0.8150
# Epoch 29/30
# 38/38 [==============================] - 10s 258ms/step - loss: 0.1883 - accuracy: 0.9433 - val_loss: 0.5583 - val_accuracy: 0.8200
# Epoch 30/30
# 38/38 [==============================] - 10s 259ms/step - loss: 0.1624 - accuracy: 0.9458 - val_loss: 0.5431 - val_accuracy: 0.8075
# 13/13 [==============================] - 2s 171ms/step - loss: 0.4491 - accuracy: 0.8500
# Training ResNet101V2...
# Epoch 1/30
# 38/38 [==============================] - 18s 296ms/step - loss: 16.7623 - accuracy: 0.5558 - val_loss: 2.2316 - val_accuracy: 0.8500
# Epoch 2/30
# 38/38 [==============================] - 9s 246ms/step - loss: 1.8278 - accuracy: 0.8892 - val_loss: 1.3299 - val_accuracy: 0.8850
# Epoch 3/30
# 38/38 [==============================] - 9s 231ms/step - loss: 0.6644 - accuracy: 0.9450 - val_loss: 1.8730 - val_accuracy: 0.8725
# Epoch 4/30
# 38/38 [==============================] - 9s 233ms/step - loss: 0.3111 - accuracy: 0.9650 - val_loss: 1.4131 - val_accuracy: 0.8925
# Epoch 5/30
# 38/38 [==============================] - 9s 234ms/step - loss: 0.2553 - accuracy: 0.9767 - val_loss: 1.9690 - val_accuracy: 0.8725
# Epoch 6/30
# 38/38 [==============================] - 9s 231ms/step - loss: 0.3935 - accuracy: 0.9717 - val_loss: 1.5402 - val_accuracy: 0.9125
# Epoch 7/30
# 38/38 [==============================] - 9s 233ms/step - loss: 0.2174 - accuracy: 0.9767 - val_loss: 1.9744 - val_accuracy: 0.8900
# Epoch 8/30
# 38/38 [==============================] - 9s 231ms/step - loss: 0.2218 - accuracy: 0.9750 - val_loss: 2.6941 - val_accuracy: 0.8750
# Epoch 9/30
# 38/38 [==============================] - 9s 229ms/step - loss: 0.3059 - accuracy: 0.9767 - val_loss: 2.4773 - val_accuracy: 0.8750
# Epoch 10/30
# 38/38 [==============================] - 9s 227ms/step - loss: 0.4642 - accuracy: 0.9692 - val_loss: 3.0216 - val_accuracy: 0.8525
# Epoch 11/30
# 38/38 [==============================] - 9s 231ms/step - loss: 0.6352 - accuracy: 0.9633 - val_loss: 3.2043 - val_accuracy: 0.8725
# Epoch 12/30
# 38/38 [==============================] - 9s 235ms/step - loss: 0.2983 - accuracy: 0.9792 - val_loss: 2.0901 - val_accuracy: 0.9075
# Epoch 13/30
# 38/38 [==============================] - 9s 245ms/step - loss: 0.3494 - accuracy: 0.9767 - val_loss: 2.6393 - val_accuracy: 0.8925
# Epoch 14/30
# 38/38 [==============================] - 9s 230ms/step - loss: 0.5800 - accuracy: 0.9692 - val_loss: 2.7313 - val_accuracy: 0.8675
# Epoch 15/30
# 38/38 [==============================] - 9s 233ms/step - loss: 0.3207 - accuracy: 0.9783 - val_loss: 2.2222 - val_accuracy: 0.8825
# Epoch 16/30
# 38/38 [==============================] - 9s 246ms/step - loss: 0.3334 - accuracy: 0.9833 - val_loss: 3.5261 - val_accuracy: 0.8775
# Epoch 17/30
# 38/38 [==============================] - 9s 230ms/step - loss: 0.3811 - accuracy: 0.9792 - val_loss: 1.7410 - val_accuracy: 0.9200
# Epoch 18/30
# 38/38 [==============================] - 9s 231ms/step - loss: 0.5272 - accuracy: 0.9725 - val_loss: 2.3967 - val_accuracy: 0.8975
# Epoch 19/30
# 38/38 [==============================] - 9s 232ms/step - loss: 0.5459 - accuracy: 0.9800 - val_loss: 2.1984 - val_accuracy: 0.9150
# Epoch 20/30
# 38/38 [==============================] - 9s 230ms/step - loss: 0.2642 - accuracy: 0.9783 - val_loss: 3.0198 - val_accuracy: 0.9100
# Epoch 21/30
# 38/38 [==============================] - 9s 229ms/step - loss: 0.1954 - accuracy: 0.9858 - val_loss: 3.2815 - val_accuracy: 0.8925
# Epoch 22/30
# 38/38 [==============================] - 9s 232ms/step - loss: 0.3198 - accuracy: 0.9833 - val_loss: 2.5937 - val_accuracy: 0.9150
# Epoch 23/30
# 38/38 [==============================] - 9s 232ms/step - loss: 0.3448 - accuracy: 0.9817 - val_loss: 3.7936 - val_accuracy: 0.8700
# Epoch 24/30
# 38/38 [==============================] - 9s 245ms/step - loss: 0.6524 - accuracy: 0.9725 - val_loss: 5.1834 - val_accuracy: 0.8400
# Epoch 25/30
# 38/38 [==============================] - 9s 229ms/step - loss: 0.4418 - accuracy: 0.9825 - val_loss: 2.1615 - val_accuracy: 0.9075
# Epoch 26/30
# 38/38 [==============================] - 9s 229ms/step - loss: 0.8923 - accuracy: 0.9817 - val_loss: 3.3529 - val_accuracy: 0.8950
# Epoch 27/30
# 38/38 [==============================] - 9s 231ms/step - loss: 0.3393 - accuracy: 0.9917 - val_loss: 3.4025 - val_accuracy: 0.9100
# Epoch 28/30
# 38/38 [==============================] - 9s 233ms/step - loss: 0.7082 - accuracy: 0.9783 - val_loss: 2.5513 - val_accuracy: 0.9175
# Epoch 29/30
# 38/38 [==============================] - 9s 229ms/step - loss: 0.0792 - accuracy: 0.9942 - val_loss: 3.0247 - val_accuracy: 0.9050
# Epoch 30/30
# 38/38 [==============================] - 9s 232ms/step - loss: 0.2884 - accuracy: 0.9842 - val_loss: 1.7667 - val_accuracy: 0.9325
# 13/13 [==============================] - 2s 153ms/step - loss: 2.3517 - accuracy: 0.9250
# Training ResNet152...
# Epoch 1/30
# 38/38 [==============================] - 27s 478ms/step - loss: 11.1402 - accuracy: 0.1850 - val_loss: 1.8924 - val_accuracy: 0.4650
# Epoch 2/30
# 38/38 [==============================] - 14s 360ms/step - loss: 1.6512 - accuracy: 0.4967 - val_loss: 1.4075 - val_accuracy: 0.5800
# Epoch 3/30
# 38/38 [==============================] - 14s 361ms/step - loss: 1.2850 - accuracy: 0.6125 - val_loss: 1.1172 - val_accuracy: 0.6725
# Epoch 4/30
# 38/38 [==============================] - 14s 360ms/step - loss: 1.0877 - accuracy: 0.6417 - val_loss: 0.9457 - val_accuracy: 0.6850
# Epoch 5/30
# 38/38 [==============================] - 14s 357ms/step - loss: 0.7711 - accuracy: 0.7567 - val_loss: 0.7484 - val_accuracy: 0.7450
# Epoch 6/30
# 38/38 [==============================] - 13s 357ms/step - loss: 0.7017 - accuracy: 0.7708 - val_loss: 0.7124 - val_accuracy: 0.7575
# Epoch 7/30
# 38/38 [==============================] - 14s 359ms/step - loss: 0.6304 - accuracy: 0.7933 - val_loss: 0.6893 - val_accuracy: 0.7675
# Epoch 8/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.5769 - accuracy: 0.8058 - val_loss: 0.6334 - val_accuracy: 0.7775
# Epoch 9/30
# 38/38 [==============================] - 14s 359ms/step - loss: 0.5324 - accuracy: 0.8292 - val_loss: 0.6462 - val_accuracy: 0.7950
# Epoch 10/30
# 38/38 [==============================] - 14s 357ms/step - loss: 0.4511 - accuracy: 0.8483 - val_loss: 0.6772 - val_accuracy: 0.7850
# Epoch 11/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.4284 - accuracy: 0.8625 - val_loss: 0.5215 - val_accuracy: 0.8100
# Epoch 12/30
# 38/38 [==============================] - 14s 363ms/step - loss: 0.3713 - accuracy: 0.8892 - val_loss: 0.5128 - val_accuracy: 0.8050
# Epoch 13/30
# 38/38 [==============================] - 14s 360ms/step - loss: 0.3422 - accuracy: 0.8867 - val_loss: 0.5053 - val_accuracy: 0.8025
# Epoch 14/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.3388 - accuracy: 0.8842 - val_loss: 0.4419 - val_accuracy: 0.8475
# Epoch 15/30
# 38/38 [==============================] - 14s 357ms/step - loss: 0.3002 - accuracy: 0.9008 - val_loss: 0.5291 - val_accuracy: 0.8125
# Epoch 16/30
# 38/38 [==============================] - 13s 356ms/step - loss: 0.3515 - accuracy: 0.8775 - val_loss: 0.4916 - val_accuracy: 0.8150
# Epoch 17/30
# 38/38 [==============================] - 15s 409ms/step - loss: 0.2944 - accuracy: 0.8983 - val_loss: 0.5134 - val_accuracy: 0.7975
# Epoch 18/30
# 38/38 [==============================] - 14s 357ms/step - loss: 0.2659 - accuracy: 0.9008 - val_loss: 0.5545 - val_accuracy: 0.7825
# Epoch 19/30
# 38/38 [==============================] - 14s 363ms/step - loss: 0.2457 - accuracy: 0.9167 - val_loss: 0.4884 - val_accuracy: 0.8475
# Epoch 20/30
# 38/38 [==============================] - 14s 361ms/step - loss: 0.2535 - accuracy: 0.9150 - val_loss: 0.4625 - val_accuracy: 0.8275
# Epoch 21/30
# 38/38 [==============================] - 15s 410ms/step - loss: 0.2163 - accuracy: 0.9292 - val_loss: 0.4661 - val_accuracy: 0.8300
# Epoch 22/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.1884 - accuracy: 0.9367 - val_loss: 0.4555 - val_accuracy: 0.8425
# Epoch 23/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.1776 - accuracy: 0.9408 - val_loss: 0.5153 - val_accuracy: 0.8550
# Epoch 24/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.1628 - accuracy: 0.9475 - val_loss: 0.4031 - val_accuracy: 0.8700
# Epoch 25/30
# 38/38 [==============================] - 14s 359ms/step - loss: 0.1946 - accuracy: 0.9400 - val_loss: 0.4328 - val_accuracy: 0.8525
# Epoch 26/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.2065 - accuracy: 0.9325 - val_loss: 0.4379 - val_accuracy: 0.8525
# Epoch 27/30
# 38/38 [==============================] - 14s 361ms/step - loss: 0.2307 - accuracy: 0.9267 - val_loss: 0.4475 - val_accuracy: 0.8575
# Epoch 28/30
# 38/38 [==============================] - 14s 360ms/step - loss: 0.1572 - accuracy: 0.9492 - val_loss: 0.5183 - val_accuracy: 0.8325
# Epoch 29/30
# 38/38 [==============================] - 14s 358ms/step - loss: 0.1541 - accuracy: 0.9517 - val_loss: 0.4804 - val_accuracy: 0.8450
# Epoch 30/30
# 38/38 [==============================] - 13s 357ms/step - loss: 0.1813 - accuracy: 0.9292 - val_loss: 0.4298 - val_accuracy: 0.8425
# 13/13 [==============================] - 3s 247ms/step - loss: 0.4680 - accuracy: 0.8525
# Training ResNet152V2...
# Epoch 1/30
# 38/38 [==============================] - 23s 392ms/step - loss: 10.8976 - accuracy: 0.5725 - val_loss: 2.7162 - val_accuracy: 0.8050
# Epoch 2/30
# 38/38 [==============================] - 12s 330ms/step - loss: 0.6355 - accuracy: 0.9367 - val_loss: 1.4507 - val_accuracy: 0.8575
# Epoch 3/30
# 38/38 [==============================] - 13s 329ms/step - loss: 0.3297 - accuracy: 0.9592 - val_loss: 1.0416 - val_accuracy: 0.9050
# Epoch 4/30
# 38/38 [==============================] - 13s 329ms/step - loss: 0.3409 - accuracy: 0.9650 - val_loss: 2.0838 - val_accuracy: 0.8725
# Epoch 5/30
# 38/38 [==============================] - 12s 327ms/step - loss: 0.1217 - accuracy: 0.9817 - val_loss: 1.3082 - val_accuracy: 0.8875
# Epoch 6/30
# 38/38 [==============================] - 12s 327ms/step - loss: 0.1267 - accuracy: 0.9833 - val_loss: 1.4461 - val_accuracy: 0.9025
# Epoch 7/30
# 38/38 [==============================] - 13s 333ms/step - loss: 0.3362 - accuracy: 0.9667 - val_loss: 2.8810 - val_accuracy: 0.8200
# Epoch 8/30
# 38/38 [==============================] - 12s 323ms/step - loss: 0.3313 - accuracy: 0.9583 - val_loss: 3.2000 - val_accuracy: 0.8475
# Epoch 9/30
# 38/38 [==============================] - 12s 324ms/step - loss: 0.4169 - accuracy: 0.9617 - val_loss: 1.8007 - val_accuracy: 0.8775
# Epoch 10/30
# 38/38 [==============================] - 13s 331ms/step - loss: 0.4305 - accuracy: 0.9675 - val_loss: 2.4740 - val_accuracy: 0.8725
# Epoch 11/30
# 38/38 [==============================] - 13s 330ms/step - loss: 0.1927 - accuracy: 0.9783 - val_loss: 2.4256 - val_accuracy: 0.8675
# Epoch 12/30
# 38/38 [==============================] - 12s 329ms/step - loss: 0.1857 - accuracy: 0.9817 - val_loss: 2.0233 - val_accuracy: 0.9050
# Epoch 13/30
# 38/38 [==============================] - 12s 321ms/step - loss: 0.1738 - accuracy: 0.9842 - val_loss: 2.6201 - val_accuracy: 0.8575
# Epoch 14/30
# 38/38 [==============================] - 12s 326ms/step - loss: 0.2372 - accuracy: 0.9792 - val_loss: 2.1430 - val_accuracy: 0.8975
# Epoch 15/30
# 38/38 [==============================] - 13s 333ms/step - loss: 0.1327 - accuracy: 0.9883 - val_loss: 2.9009 - val_accuracy: 0.8825
# Epoch 16/30
# 38/38 [==============================] - 13s 330ms/step - loss: 0.1404 - accuracy: 0.9900 - val_loss: 2.3501 - val_accuracy: 0.8975
# Epoch 17/30
# 38/38 [==============================] - 15s 385ms/step - loss: 0.2195 - accuracy: 0.9842 - val_loss: 2.7972 - val_accuracy: 0.8900
# Epoch 18/30
# 38/38 [==============================] - 12s 327ms/step - loss: 0.0452 - accuracy: 0.9925 - val_loss: 2.5461 - val_accuracy: 0.8850
# Epoch 19/30
# 38/38 [==============================] - 12s 325ms/step - loss: 0.3247 - accuracy: 0.9792 - val_loss: 2.2982 - val_accuracy: 0.8825
# Epoch 20/30
# 38/38 [==============================] - 13s 331ms/step - loss: 0.2701 - accuracy: 0.9850 - val_loss: 1.7958 - val_accuracy: 0.8975
# Epoch 21/30
# 38/38 [==============================] - 12s 330ms/step - loss: 0.2648 - accuracy: 0.9858 - val_loss: 2.2264 - val_accuracy: 0.8800
# Epoch 22/30
# 38/38 [==============================] - 12s 324ms/step - loss: 0.2928 - accuracy: 0.9767 - val_loss: 3.4749 - val_accuracy: 0.8475
# Epoch 23/30
# 38/38 [==============================] - 12s 327ms/step - loss: 0.4138 - accuracy: 0.9758 - val_loss: 3.1200 - val_accuracy: 0.8725
# Epoch 24/30
# 38/38 [==============================] - 13s 334ms/step - loss: 0.1522 - accuracy: 0.9858 - val_loss: 3.2577 - val_accuracy: 0.8950
# Epoch 25/30
# 38/38 [==============================] - 13s 332ms/step - loss: 0.1290 - accuracy: 0.9925 - val_loss: 2.7011 - val_accuracy: 0.9025
# Epoch 26/30
# 38/38 [==============================] - 12s 329ms/step - loss: 0.2478 - accuracy: 0.9817 - val_loss: 2.2118 - val_accuracy: 0.9050
# Epoch 27/30
# 38/38 [==============================] - 12s 325ms/step - loss: 0.2143 - accuracy: 0.9842 - val_loss: 4.1495 - val_accuracy: 0.8750
# Epoch 28/30
# 38/38 [==============================] - 12s 325ms/step - loss: 0.1133 - accuracy: 0.9883 - val_loss: 1.9457 - val_accuracy: 0.9125
# Epoch 29/30
# 38/38 [==============================] - 15s 384ms/step - loss: 0.1295 - accuracy: 0.9883 - val_loss: 3.1841 - val_accuracy: 0.8925
# Epoch 30/30
# 38/38 [==============================] - 13s 330ms/step - loss: 0.2615 - accuracy: 0.9833 - val_loss: 2.3359 - val_accuracy: 0.8975
# 13/13 [==============================] - 3s 228ms/step - loss: 2.9129 - accuracy: 0.9125

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
