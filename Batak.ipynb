# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Batak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, VGG16, ResNet50, InceptionV3, DenseNet121
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/eursamajor/Aksara/raw/main/Batak.zip'

zip_path = './Batak.zip'
extract_path = './'

response = requests.get(url)
with open(zip_path, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

#utk store data yang udah didownload dan extract
dataset_dir = os.path.join(extract_path, 'Batak')

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 1140 images belonging to 19 classes.
# Found 380 images belonging to 19 classes.
# Found 380 images belonging to 19 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'VGG16': VGG16(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'ResNet50': ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'InceptionV3': InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'MobileNetV2': MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'DenseNet121': DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training VGG16...
# Epoch 1/30
# 36/36 [==============================] - 8s 188ms/step - loss: 3.6046 - accuracy: 0.5509 - val_loss: 0.2196 - val_accuracy: 0.9289
# Epoch 2/30
# 36/36 [==============================] - 7s 184ms/step - loss: 0.1453 - accuracy: 0.9632 - val_loss: 0.0649 - val_accuracy: 0.9842
# Epoch 3/30
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0559 - accuracy: 0.9912 - val_loss: 0.0547 - val_accuracy: 0.9895
# Epoch 4/30
# 36/36 [==============================] - 7s 180ms/step - loss: 0.0335 - accuracy: 0.9939 - val_loss: 0.0555 - val_accuracy: 0.9868
# Epoch 5/30
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0269 - accuracy: 0.9939 - val_loss: 0.0293 - val_accuracy: 0.9921
# Epoch 6/30
# 36/36 [==============================] - 7s 180ms/step - loss: 0.0170 - accuracy: 0.9982 - val_loss: 0.0335 - val_accuracy: 0.9921
# Epoch 7/30
# 36/36 [==============================] - 7s 181ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9947
# Epoch 8/30
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9895
# Epoch 9/30
# 36/36 [==============================] - 8s 208ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9921
# Epoch 10/30
# 36/36 [==============================] - 6s 180ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9921
# Epoch 11/30
# 36/36 [==============================] - 7s 181ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9947
# Epoch 12/30
# 36/36 [==============================] - 7s 181ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9921
# Epoch 13/30
# 36/36 [==============================] - 7s 181ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9921
# Epoch 14/30
# 36/36 [==============================] - 7s 180ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9921
# Epoch 15/30
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9921
# Epoch 16/30
# 36/36 [==============================] - 7s 182ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9921
# Epoch 17/30
# 36/36 [==============================] - 7s 184ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9895
# Epoch 18/30
# 36/36 [==============================] - 7s 181ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9921
# Epoch 19/30
# 36/36 [==============================] - 7s 182ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9947
# Epoch 20/30
# 36/36 [==============================] - 7s 208ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9921
# Epoch 21/30
# 36/36 [==============================] - 6s 180ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9921
# Epoch 22/30
# 36/36 [==============================] - 7s 181ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9947
# Epoch 23/30
# 36/36 [==============================] - 6s 180ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9921
# Epoch 24/30
# 36/36 [==============================] - 7s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9921
# Epoch 25/30
# 36/36 [==============================] - 6s 180ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9947
# Epoch 26/30
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9921
# Epoch 27/30
# 36/36 [==============================] - 8s 207ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9947
# Epoch 28/30
# 36/36 [==============================] - 7s 180ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9921
# Epoch 29/30
# 36/36 [==============================] - 7s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9921
# Epoch 30/30
# 36/36 [==============================] - 8s 210ms/step - loss: 8.0547e-04 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9947
# 12/12 [==============================] - 2s 132ms/step - loss: 0.0225 - accuracy: 0.9947
# Training ResNet50...
# Epoch 1/30
# 36/36 [==============================] - 16s 309ms/step - loss: 16.4014 - accuracy: 0.1254 - val_loss: 2.5807 - val_accuracy: 0.1579
# Epoch 2/30
# 36/36 [==============================] - 6s 170ms/step - loss: 2.2623 - accuracy: 0.2904 - val_loss: 1.9221 - val_accuracy: 0.5737
# Epoch 3/30
# 36/36 [==============================] - 7s 202ms/step - loss: 1.9334 - accuracy: 0.4158 - val_loss: 1.5842 - val_accuracy: 0.6526
# Epoch 4/30
# 36/36 [==============================] - 6s 167ms/step - loss: 1.6069 - accuracy: 0.5342 - val_loss: 1.5546 - val_accuracy: 0.5263
# Epoch 5/30
# 36/36 [==============================] - 6s 170ms/step - loss: 1.4667 - accuracy: 0.5281 - val_loss: 1.0813 - val_accuracy: 0.7579
# Epoch 6/30
# 36/36 [==============================] - 6s 171ms/step - loss: 1.1478 - accuracy: 0.6570 - val_loss: 1.0692 - val_accuracy: 0.7289
# Epoch 7/30
# 36/36 [==============================] - 6s 168ms/step - loss: 1.0701 - accuracy: 0.6535 - val_loss: 0.9096 - val_accuracy: 0.7737
# Epoch 8/30
# 36/36 [==============================] - 6s 168ms/step - loss: 0.9556 - accuracy: 0.6851 - val_loss: 0.9056 - val_accuracy: 0.7658
# Epoch 9/30
# 36/36 [==============================] - 6s 167ms/step - loss: 0.8535 - accuracy: 0.7404 - val_loss: 0.7226 - val_accuracy: 0.8132
# Epoch 10/30
# 36/36 [==============================] - 6s 172ms/step - loss: 0.7666 - accuracy: 0.7518 - val_loss: 0.6366 - val_accuracy: 0.8211
# Epoch 11/30
# 36/36 [==============================] - 6s 169ms/step - loss: 0.7451 - accuracy: 0.7596 - val_loss: 0.6327 - val_accuracy: 0.8316
# Epoch 12/30
# 36/36 [==============================] - 6s 171ms/step - loss: 0.7651 - accuracy: 0.7526 - val_loss: 0.6346 - val_accuracy: 0.7816
# Epoch 13/30
# 36/36 [==============================] - 6s 167ms/step - loss: 0.7009 - accuracy: 0.7754 - val_loss: 0.5058 - val_accuracy: 0.8474
# Epoch 14/30
# 36/36 [==============================] - 6s 172ms/step - loss: 0.6024 - accuracy: 0.8088 - val_loss: 0.5367 - val_accuracy: 0.8632
# Epoch 15/30
# 36/36 [==============================] - 7s 201ms/step - loss: 0.5736 - accuracy: 0.8132 - val_loss: 0.4510 - val_accuracy: 0.8895
# Epoch 16/30
# 36/36 [==============================] - 6s 166ms/step - loss: 0.6268 - accuracy: 0.7895 - val_loss: 0.5415 - val_accuracy: 0.8579
# Epoch 17/30
# 36/36 [==============================] - 6s 169ms/step - loss: 0.6458 - accuracy: 0.7798 - val_loss: 0.4726 - val_accuracy: 0.8737
# Epoch 18/30
# 36/36 [==============================] - 6s 168ms/step - loss: 0.4933 - accuracy: 0.8386 - val_loss: 0.4205 - val_accuracy: 0.8605
# Epoch 19/30
# 36/36 [==============================] - 7s 204ms/step - loss: 0.4724 - accuracy: 0.8430 - val_loss: 0.3725 - val_accuracy: 0.8842
# Epoch 20/30
# 36/36 [==============================] - 6s 167ms/step - loss: 0.4920 - accuracy: 0.8307 - val_loss: 0.4220 - val_accuracy: 0.8632
# Epoch 21/30
# 36/36 [==============================] - 6s 172ms/step - loss: 0.4854 - accuracy: 0.8325 - val_loss: 0.3406 - val_accuracy: 0.9132
# Epoch 22/30
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4262 - accuracy: 0.8623 - val_loss: 0.3267 - val_accuracy: 0.9158
# Epoch 23/30
# 36/36 [==============================] - 6s 172ms/step - loss: 0.3974 - accuracy: 0.8675 - val_loss: 0.3519 - val_accuracy: 0.8895
# Epoch 24/30
# 36/36 [==============================] - 6s 168ms/step - loss: 0.4180 - accuracy: 0.8544 - val_loss: 0.3576 - val_accuracy: 0.8789
# Epoch 25/30
# 36/36 [==============================] - 6s 168ms/step - loss: 0.3961 - accuracy: 0.8684 - val_loss: 0.4117 - val_accuracy: 0.8658
# Epoch 26/30
# 36/36 [==============================] - 6s 170ms/step - loss: 0.4220 - accuracy: 0.8588 - val_loss: 0.3357 - val_accuracy: 0.9105
# Epoch 27/30
# 36/36 [==============================] - 6s 168ms/step - loss: 0.4325 - accuracy: 0.8632 - val_loss: 0.3264 - val_accuracy: 0.8868
# Epoch 28/30
# 36/36 [==============================] - 7s 203ms/step - loss: 0.3752 - accuracy: 0.8702 - val_loss: 0.2701 - val_accuracy: 0.9395
# Epoch 29/30
# 36/36 [==============================] - 6s 170ms/step - loss: 0.3814 - accuracy: 0.8816 - val_loss: 0.4623 - val_accuracy: 0.8500
# Epoch 30/30
# 36/36 [==============================] - 6s 167ms/step - loss: 0.4268 - accuracy: 0.8667 - val_loss: 0.3568 - val_accuracy: 0.8737
# 12/12 [==============================] - 1s 110ms/step - loss: 0.3526 - accuracy: 0.8895
# Training InceptionV3...
# Epoch 1/30
# 36/36 [==============================] - 19s 315ms/step - loss: 13.2002 - accuracy: 0.5711 - val_loss: 1.2078 - val_accuracy: 0.8289
# Epoch 2/30
# 36/36 [==============================] - 4s 112ms/step - loss: 0.5487 - accuracy: 0.9096 - val_loss: 0.2920 - val_accuracy: 0.9211
# Epoch 3/30
# 36/36 [==============================] - 5s 125ms/step - loss: 0.0995 - accuracy: 0.9719 - val_loss: 0.2470 - val_accuracy: 0.9395
# Epoch 4/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.1318 - accuracy: 0.9693 - val_loss: 0.2289 - val_accuracy: 0.9526
# Epoch 5/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0760 - accuracy: 0.9798 - val_loss: 0.1649 - val_accuracy: 0.9526
# Epoch 6/30
# 36/36 [==============================] - 5s 125ms/step - loss: 0.0440 - accuracy: 0.9868 - val_loss: 0.2804 - val_accuracy: 0.9526
# Epoch 7/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0466 - accuracy: 0.9886 - val_loss: 0.1918 - val_accuracy: 0.9553
# Epoch 8/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0212 - accuracy: 0.9939 - val_loss: 0.0981 - val_accuracy: 0.9684
# Epoch 9/30
# 36/36 [==============================] - 4s 116ms/step - loss: 0.0122 - accuracy: 0.9947 - val_loss: 0.1301 - val_accuracy: 0.9658
# Epoch 10/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0050 - accuracy: 0.9974 - val_loss: 0.1249 - val_accuracy: 0.9684
# Epoch 11/30
# 36/36 [==============================] - 4s 110ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.1406 - val_accuracy: 0.9658
# Epoch 12/30
# 36/36 [==============================] - 4s 118ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9684
# Epoch 13/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0030 - accuracy: 0.9974 - val_loss: 0.1953 - val_accuracy: 0.9579
# Epoch 14/30
# 36/36 [==============================] - 4s 110ms/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.1898 - val_accuracy: 0.9658
# Epoch 15/30
# 36/36 [==============================] - 4s 114ms/step - loss: 0.0358 - accuracy: 0.9877 - val_loss: 0.1105 - val_accuracy: 0.9632
# Epoch 16/30
# 36/36 [==============================] - 4s 114ms/step - loss: 0.0496 - accuracy: 0.9851 - val_loss: 0.3067 - val_accuracy: 0.9368
# Epoch 17/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0592 - accuracy: 0.9825 - val_loss: 0.2939 - val_accuracy: 0.9421
# Epoch 18/30
# 36/36 [==============================] - 4s 122ms/step - loss: 0.1575 - accuracy: 0.9719 - val_loss: 0.5203 - val_accuracy: 0.9263
# Epoch 19/30
# 36/36 [==============================] - 4s 113ms/step - loss: 0.2027 - accuracy: 0.9588 - val_loss: 0.4746 - val_accuracy: 0.9158
# Epoch 20/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.3511 - accuracy: 0.9474 - val_loss: 0.4069 - val_accuracy: 0.9421
# Epoch 21/30
# 36/36 [==============================] - 4s 115ms/step - loss: 0.2813 - accuracy: 0.9526 - val_loss: 0.1824 - val_accuracy: 0.9684
# Epoch 22/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0917 - accuracy: 0.9833 - val_loss: 0.3239 - val_accuracy: 0.9632
# Epoch 23/30
# 36/36 [==============================] - 4s 110ms/step - loss: 0.1398 - accuracy: 0.9763 - val_loss: 0.2963 - val_accuracy: 0.9553
# Epoch 24/30
# 36/36 [==============================] - 5s 126ms/step - loss: 0.0863 - accuracy: 0.9860 - val_loss: 0.3752 - val_accuracy: 0.9421
# Epoch 25/30
# 36/36 [==============================] - 4s 110ms/step - loss: 0.1035 - accuracy: 0.9807 - val_loss: 0.3495 - val_accuracy: 0.9474
# Epoch 26/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0895 - accuracy: 0.9886 - val_loss: 0.1753 - val_accuracy: 0.9605
# Epoch 27/30
# 36/36 [==============================] - 4s 116ms/step - loss: 0.0261 - accuracy: 0.9947 - val_loss: 0.3078 - val_accuracy: 0.9632
# Epoch 28/30
# 36/36 [==============================] - 4s 111ms/step - loss: 0.0315 - accuracy: 0.9921 - val_loss: 0.7803 - val_accuracy: 0.9184
# Epoch 29/30
# 36/36 [==============================] - 4s 110ms/step - loss: 0.0737 - accuracy: 0.9904 - val_loss: 0.5588 - val_accuracy: 0.9368
# Epoch 30/30
# 36/36 [==============================] - 4s 115ms/step - loss: 0.1044 - accuracy: 0.9860 - val_loss: 0.6112 - val_accuracy: 0.9368
# 12/12 [==============================] - 1s 74ms/step - loss: 1.0082 - accuracy: 0.9289
# Training MobileNetV2...
# Epoch 1/30
# 36/36 [==============================] - 32s 181ms/step - loss: 15.1424 - accuracy: 0.6895 - val_loss: 0.8940 - val_accuracy: 0.9447
# Epoch 2/30
# 36/36 [==============================] - 3s 90ms/step - loss: 0.7792 - accuracy: 0.9544 - val_loss: 0.8564 - val_accuracy: 0.9421
# Epoch 3/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.5529 - accuracy: 0.9711 - val_loss: 0.4180 - val_accuracy: 0.9684
# Epoch 4/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.2901 - accuracy: 0.9789 - val_loss: 0.9567 - val_accuracy: 0.9553
# Epoch 5/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.1709 - accuracy: 0.9868 - val_loss: 0.2043 - val_accuracy: 0.9789
# Epoch 6/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.0483 - accuracy: 0.9947 - val_loss: 0.2046 - val_accuracy: 0.9868
# Epoch 7/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.0993 - accuracy: 0.9921 - val_loss: 0.4484 - val_accuracy: 0.9632
# Epoch 8/30
# 36/36 [==============================] - 3s 87ms/step - loss: 0.1578 - accuracy: 0.9877 - val_loss: 0.4844 - val_accuracy: 0.9605
# Epoch 9/30
# 36/36 [==============================] - 3s 92ms/step - loss: 0.1087 - accuracy: 0.9921 - val_loss: 0.4066 - val_accuracy: 0.9737
# Epoch 10/30
# 36/36 [==============================] - 3s 81ms/step - loss: 0.0592 - accuracy: 0.9947 - val_loss: 0.2751 - val_accuracy: 0.9737
# Epoch 11/30
# 36/36 [==============================] - 3s 81ms/step - loss: 0.0368 - accuracy: 0.9930 - val_loss: 0.3863 - val_accuracy: 0.9711
# Epoch 12/30
# 36/36 [==============================] - 3s 82ms/step - loss: 0.0978 - accuracy: 0.9939 - val_loss: 0.6735 - val_accuracy: 0.9737
# Epoch 13/30
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2114 - accuracy: 0.9904 - val_loss: 0.8596 - val_accuracy: 0.9632
# Epoch 14/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2340 - accuracy: 0.9807 - val_loss: 0.8545 - val_accuracy: 0.9605
# Epoch 15/30
# 36/36 [==============================] - 3s 88ms/step - loss: 0.3463 - accuracy: 0.9816 - val_loss: 0.8604 - val_accuracy: 0.9500
# Epoch 16/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.3935 - accuracy: 0.9789 - val_loss: 1.1471 - val_accuracy: 0.9658
# Epoch 17/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2863 - accuracy: 0.9860 - val_loss: 0.7216 - val_accuracy: 0.9684
# Epoch 18/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2863 - accuracy: 0.9842 - val_loss: 0.9931 - val_accuracy: 0.9526
# Epoch 19/30
# 36/36 [==============================] - 3s 95ms/step - loss: 0.1886 - accuracy: 0.9895 - val_loss: 0.3582 - val_accuracy: 0.9816
# Epoch 20/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.0551 - accuracy: 0.9956 - val_loss: 0.9296 - val_accuracy: 0.9658
# Epoch 21/30
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2181 - accuracy: 0.9904 - val_loss: 0.2965 - val_accuracy: 0.9842
# Epoch 22/30
# 36/36 [==============================] - 4s 97ms/step - loss: 0.2125 - accuracy: 0.9939 - val_loss: 0.8411 - val_accuracy: 0.9763
# Epoch 23/30
# 36/36 [==============================] - 3s 79ms/step - loss: 0.0365 - accuracy: 0.9965 - val_loss: 1.2249 - val_accuracy: 0.9447
# Epoch 24/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.0755 - accuracy: 0.9930 - val_loss: 0.2899 - val_accuracy: 0.9763
# Epoch 25/30
# 36/36 [==============================] - 4s 99ms/step - loss: 0.1904 - accuracy: 0.9904 - val_loss: 0.2701 - val_accuracy: 0.9868
# Epoch 26/30
# 36/36 [==============================] - 3s 81ms/step - loss: 0.2214 - accuracy: 0.9904 - val_loss: 0.8740 - val_accuracy: 0.9737
# Epoch 27/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.4539 - accuracy: 0.9851 - val_loss: 2.3587 - val_accuracy: 0.9368
# Epoch 28/30
# 36/36 [==============================] - 3s 79ms/step - loss: 0.3893 - accuracy: 0.9842 - val_loss: 0.8441 - val_accuracy: 0.9711
# Epoch 29/30
# 36/36 [==============================] - 3s 86ms/step - loss: 0.0758 - accuracy: 0.9947 - val_loss: 1.0388 - val_accuracy: 0.9684
# Epoch 30/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.1526 - accuracy: 0.9939 - val_loss: 1.1502 - val_accuracy: 0.9579
# 12/12 [==============================] - 1s 50ms/step - loss: 1.8706 - accuracy: 0.9526
# Training DenseNet121...
# Epoch 1/30
# 36/36 [==============================] - 25s 410ms/step - loss: 9.9640 - accuracy: 0.6649 - val_loss: 0.5333 - val_accuracy: 0.9289
# Epoch 2/30
# 36/36 [==============================] - 6s 153ms/step - loss: 0.3558 - accuracy: 0.9509 - val_loss: 0.8095 - val_accuracy: 0.9053
# Epoch 3/30
# 36/36 [==============================] - 5s 145ms/step - loss: 0.2136 - accuracy: 0.9675 - val_loss: 0.7626 - val_accuracy: 0.9368
# Epoch 4/30
# 36/36 [==============================] - 5s 150ms/step - loss: 0.3062 - accuracy: 0.9667 - val_loss: 0.5186 - val_accuracy: 0.9474
# Epoch 5/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.1213 - accuracy: 0.9807 - val_loss: 0.4104 - val_accuracy: 0.9526
# Epoch 6/30
# 36/36 [==============================] - 5s 150ms/step - loss: 0.1314 - accuracy: 0.9807 - val_loss: 0.3553 - val_accuracy: 0.9447
# Epoch 7/30
# 36/36 [==============================] - 5s 145ms/step - loss: 0.1168 - accuracy: 0.9798 - val_loss: 0.1312 - val_accuracy: 0.9868
# Epoch 8/30
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0430 - accuracy: 0.9930 - val_loss: 0.3799 - val_accuracy: 0.9579
# Epoch 9/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.0319 - accuracy: 0.9930 - val_loss: 0.2897 - val_accuracy: 0.9711
# Epoch 10/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.0330 - accuracy: 0.9965 - val_loss: 0.2271 - val_accuracy: 0.9684
# Epoch 11/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.0557 - accuracy: 0.9930 - val_loss: 0.5705 - val_accuracy: 0.9579
# Epoch 12/30
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0655 - accuracy: 0.9930 - val_loss: 0.2389 - val_accuracy: 0.9711
# Epoch 13/30
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0189 - accuracy: 0.9956 - val_loss: 0.3304 - val_accuracy: 0.9658
# Epoch 14/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.0398 - accuracy: 0.9921 - val_loss: 0.2378 - val_accuracy: 0.9684
# Epoch 15/30
# 36/36 [==============================] - 5s 151ms/step - loss: 0.0421 - accuracy: 0.9877 - val_loss: 0.2026 - val_accuracy: 0.9711
# Epoch 16/30
# 36/36 [==============================] - 5s 147ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.1842 - val_accuracy: 0.9684
# Epoch 17/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.1181 - accuracy: 0.9816 - val_loss: 0.1012 - val_accuracy: 0.9842
# Epoch 18/30
# 36/36 [==============================] - 5s 150ms/step - loss: 0.0736 - accuracy: 0.9860 - val_loss: 0.4681 - val_accuracy: 0.9447
# Epoch 19/30
# 36/36 [==============================] - 5s 147ms/step - loss: 0.1484 - accuracy: 0.9754 - val_loss: 0.6862 - val_accuracy: 0.9447
# Epoch 20/30
# 36/36 [==============================] - 5s 151ms/step - loss: 0.1187 - accuracy: 0.9789 - val_loss: 0.4034 - val_accuracy: 0.9579
# Epoch 21/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.1355 - accuracy: 0.9798 - val_loss: 0.3488 - val_accuracy: 0.9737
# Epoch 22/30
# 36/36 [==============================] - 5s 150ms/step - loss: 0.2446 - accuracy: 0.9711 - val_loss: 0.4256 - val_accuracy: 0.9553
# Epoch 23/30
# 36/36 [==============================] - 5s 147ms/step - loss: 0.1348 - accuracy: 0.9816 - val_loss: 0.7069 - val_accuracy: 0.9395
# Epoch 24/30
# 36/36 [==============================] - 5s 149ms/step - loss: 0.2472 - accuracy: 0.9737 - val_loss: 0.4973 - val_accuracy: 0.9711
# Epoch 25/30
# 36/36 [==============================] - 5s 148ms/step - loss: 0.0984 - accuracy: 0.9851 - val_loss: 0.1230 - val_accuracy: 0.9868
# Epoch 26/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.0530 - accuracy: 0.9886 - val_loss: 0.3654 - val_accuracy: 0.9711
# Epoch 27/30
# 36/36 [==============================] - 5s 152ms/step - loss: 0.0826 - accuracy: 0.9877 - val_loss: 0.5311 - val_accuracy: 0.9579
# Epoch 28/30
# 36/36 [==============================] - 5s 146ms/step - loss: 0.1518 - accuracy: 0.9807 - val_loss: 0.3946 - val_accuracy: 0.9684
# Epoch 29/30
# 36/36 [==============================] - 5s 145ms/step - loss: 0.0675 - accuracy: 0.9904 - val_loss: 0.2246 - val_accuracy: 0.9711
# Epoch 30/30
# 36/36 [==============================] - 5s 149ms/step - loss: 0.0367 - accuracy: 0.9947 - val_loss: 0.4354 - val_accuracy: 0.9711
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4200 - accuracy: 0.9658

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
