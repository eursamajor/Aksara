# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Pallawa_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2, ResNet101, ResNet101V2, ResNet152, ResNet152V2
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
dataset_dir = './drive/MyDrive/Aksara/Pallawa'

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 2376 images belonging to 33 classes.
# Found 792 images belonging to 33 classes.
# Found 792 images belonging to 33 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'ResNet50V2': ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'ResNet101': ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'ResNet101V2': ResNet101V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'ResNet152': ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'ResNet152V2': ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training ResNet50V2...
# Epoch 1/30
# 75/75 [==============================] - 24s 204ms/step - loss: 3.2893 - accuracy: 0.8245 - val_loss: 0.1794 - val_accuracy: 0.9735
# Epoch 2/30
# 75/75 [==============================] - 11s 142ms/step - loss: 0.1084 - accuracy: 0.9819 - val_loss: 0.0819 - val_accuracy: 0.9874
# Epoch 3/30
# 75/75 [==============================] - 11s 142ms/step - loss: 0.1277 - accuracy: 0.9861 - val_loss: 0.1539 - val_accuracy: 0.9836
# Epoch 4/30
# 75/75 [==============================] - 11s 144ms/step - loss: 0.0655 - accuracy: 0.9886 - val_loss: 0.1192 - val_accuracy: 0.9912
# Epoch 5/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.8277 - accuracy: 0.4769 - val_loss: 1.6629 - val_accuracy: 0.5922
# Epoch 8/30
# 75/75 [==============================] - 27s 356ms/step - loss: 1.7616 - accuracy: 0.5021 - val_loss: 1.4384 - val_accuracy: 0.6465
# Epoch 9/30
# 75/75 [==============================] - 27s 356ms/step - loss: 1.6514 - accuracy: 0.5320 - val_loss: 1.4227 - val_accuracy: 0.6338
# Epoch 10/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.6019 - accuracy: 0.5492 - val_loss: 1.3192 - val_accuracy: 0.6540
# Epoch 11/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.5347 - accuracy: 0.5711 - val_loss: 1.2438 - val_accuracy: 0.6641
# Epoch 12/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.5021 - accuracy: 0.5610 - val_loss: 1.1690 - val_accuracy: 0.6843
# Epoch 13/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.4115 - accuracy: 0.6006 - val_loss: 1.1008 - val_accuracy: 0.7323
# Epoch 14/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.3832 - accuracy: 0.5993 - val_loss: 1.2466 - val_accuracy: 0.6566
# Epoch 15/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.4070 - accuracy: 0.5976 - val_loss: 1.1313 - val_accuracy: 0.6944
# Epoch 16/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.3565 - accuracy: 0.6048 - val_loss: 1.2353 - val_accuracy: 0.6490
# Epoch 17/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.3878 - accuracy: 0.5972 - val_loss: 1.0384 - val_accuracy: 0.7412
# Epoch 18/30
# 75/75 [==============================] - 27s 356ms/step - loss: 1.2971 - accuracy: 0.6267 - val_loss: 1.1427 - val_accuracy: 0.7033
# Epoch 19/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.3372 - accuracy: 0.6107 - val_loss: 1.0680 - val_accuracy: 0.7348
# Epoch 20/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.3003 - accuracy: 0.6178 - val_loss: 1.1385 - val_accuracy: 0.6856
# Epoch 21/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.3280 - accuracy: 0.6094 - val_loss: 1.1580 - val_accuracy: 0.6831
# Epoch 22/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.2919 - accuracy: 0.6170 - val_loss: 1.0815 - val_accuracy: 0.7096
# Epoch 23/30
# 75/75 [==============================] - 31s 409ms/step - loss: 1.1980 - accuracy: 0.6486 - val_loss: 0.8023 - val_accuracy: 0.7753
# Epoch 24/30
# 75/75 [==============================] - 27s 357ms/step - loss: 1.0970 - accuracy: 0.6843 - val_loss: 0.8865 - val_accuracy: 0.7551
# Epoch 25/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.1246 - accuracy: 0.6738 - val_loss: 0.9791 - val_accuracy: 0.7449
# Epoch 26/30
# 75/75 [==============================] - 26s 353ms/step - loss: 1.0711 - accuracy: 0.6864 - val_loss: 0.9321 - val_accuracy: 0.7525
# Epoch 27/30
# 75/75 [==============================] - 27s 355ms/step - loss: 1.1596 - accuracy: 0.6637 - val_loss: 1.1169 - val_accuracy: 0.7121
# Epoch 28/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.1507 - accuracy: 0.6629 - val_loss: 0.9014 - val_accuracy: 0.7664
# Epoch 29/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.0869 - accuracy: 0.6873 - val_loss: 0.8659 - val_accuracy: 0.7891
# Epoch 30/30
# 75/75 [==============================] - 27s 354ms/step - loss: 1.1133 - accuracy: 0.6620 - val_loss: 0.8500 - val_accuracy: 0.7778
# 25/25 [==============================] - 6s 249ms/step - loss: 0.9493 - accuracy: 0.7412
# Training ResNet152V2...
# Epoch 1/30
# 75/75 [==============================] - 36s 358ms/step - loss: 3.6390 - accuracy: 0.8098 - val_loss: 0.2855 - val_accuracy: 0.9684
# Epoch 2/30
# 75/75 [==============================] - 29s 386ms/step - loss: 0.0714 - accuracy: 0.9836 - val_loss: 0.0508 - val_accuracy: 0.9899
# Epoch 3/30
# 75/75 [==============================] - 24s 320ms/step - loss: 0.0270 - accuracy: 0.9924 - val_loss: 0.0632 - val_accuracy: 0.9874
# Epoch 4/30
# 75/75 [==============================] - 24s 324ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.0382 - val_accuracy: 0.9937
# Epoch 5/30
# 75/75 [==============================] - 24s 326ms/step - loss: 0.0850 - accuracy: 0.9870 - val_loss: 0.0694 - val_accuracy: 0.9874
# Epoch 6/30
# 75/75 [==============================] - 24s 320ms/step - loss: 0.1133 - accuracy: 0.9815 - val_loss: 0.1242 - val_accuracy: 0.9874
# Epoch 7/30
# 75/75 [==============================] - 29s 383ms/step - loss: 0.1410 - accuracy: 0.9848 - val_loss: 0.0529 - val_accuracy: 0.9848
# Epoch 8/30
# 75/75 [==============================] - 24s 323ms/step - loss: 0.3771 - accuracy: 0.9672 - val_loss: 0.7927 - val_accuracy: 0.9697
# Epoch 9/30
# 75/75 [==============================] - 29s 387ms/step - loss: 0.5529 - accuracy: 0.9646 - val_loss: 0.2155 - val_accuracy: 0.9811
# Epoch 10/30
# 75/75 [==============================] - 24s 320ms/step - loss: 0.3663 - accuracy: 0.9722 - val_loss: 0.9825 - val_accuracy: 0.9848
# Epoch 11/30
# 75/75 [==============================] - 29s 384ms/step - loss: 0.3393 - accuracy: 0.9827 - val_loss: 0.3718 - val_accuracy: 0.9836
# Epoch 12/30
# 75/75 [==============================] - 24s 323ms/step - loss: 0.1012 - accuracy: 0.9928 - val_loss: 0.0659 - val_accuracy: 0.9912
# Epoch 13/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.0273 - accuracy: 0.9975 - val_loss: 0.0688 - val_accuracy: 0.9949
# Epoch 14/30
# 75/75 [==============================] - 29s 385ms/step - loss: 0.0206 - accuracy: 0.9979 - val_loss: 0.2476 - val_accuracy: 0.9886
# Epoch 15/30
# 75/75 [==============================] - 24s 320ms/step - loss: 0.0363 - accuracy: 0.9979 - val_loss: 0.0544 - val_accuracy: 0.9949
# Epoch 16/30
# 75/75 [==============================] - 29s 387ms/step - loss: 6.6963e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9937
# Epoch 17/30
# 75/75 [==============================] - 24s 322ms/step - loss: 1.5408e-05 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9937
# Epoch 18/30
# 75/75 [==============================] - 29s 385ms/step - loss: 6.9381e-06 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9937
# Epoch 19/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.0813 - val_accuracy: 0.9937
# Epoch 20/30
# 75/75 [==============================] - 24s 324ms/step - loss: 0.0306 - accuracy: 0.9975 - val_loss: 0.1497 - val_accuracy: 0.9899
# Epoch 21/30
# 75/75 [==============================] - 29s 384ms/step - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.1529 - val_accuracy: 0.9937
# Epoch 22/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.0274 - accuracy: 0.9975 - val_loss: 0.0748 - val_accuracy: 0.9949
# Epoch 23/30
# 75/75 [==============================] - 29s 386ms/step - loss: 0.0139 - accuracy: 0.9992 - val_loss: 0.1100 - val_accuracy: 0.9962
# Epoch 24/30
# 75/75 [==============================] - 24s 323ms/step - loss: 0.0065 - accuracy: 0.9992 - val_loss: 0.2204 - val_accuracy: 0.9912
# Epoch 25/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.0382 - accuracy: 0.9962 - val_loss: 0.1023 - val_accuracy: 0.9949
# Epoch 26/30
# 75/75 [==============================] - 29s 384ms/step - loss: 0.0571 - accuracy: 0.9958 - val_loss: 0.1900 - val_accuracy: 0.9861
# Epoch 27/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.1166 - accuracy: 0.9937 - val_loss: 0.1652 - val_accuracy: 0.9937
# Epoch 28/30
# 75/75 [==============================] - 29s 386ms/step - loss: 0.0682 - accuracy: 0.9954 - val_loss: 0.0945 - val_accuracy: 0.9949
# Epoch 29/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.2180 - accuracy: 0.9907 - val_loss: 0.0991 - val_accuracy: 0.9912
# Epoch 30/30
# 75/75 [==============================] - 24s 322ms/step - loss: 0.8557 - accuracy: 0.9756 - val_loss: 0.9340 - val_accuracy: 0.9571
# 25/25 [==============================] - 6s 224ms/step - loss: 1.2455 - accuracy: 0.9457

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
