# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Lontara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, VGG16, ResNet50, InceptionV3, DenseNet121
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/eursamajor/Aksara/raw/main/Lontara.zip'

zip_path = './Lontara.zip'
extract_path = './'

response = requests.get(url)
with open(zip_path, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

#utk store data yang udah didownload dan extract
dataset_dir = os.path.join(extract_path, 'Lontara')

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 1379 images belonging to 23 classes.
# Found 460 images belonging to 23 classes.
# Found 460 images belonging to 23 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'VGG16': VGG16(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'ResNet50': ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'InceptionV3': InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'MobileNetV2': MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'DenseNet121': DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training VGG16...
# Epoch 1/30
# 44/44 [==============================] - 22s 272ms/step - loss: 2.9342 - accuracy: 0.4685 - val_loss: 0.4354 - val_accuracy: 0.9000
# Epoch 2/30
# 44/44 [==============================] - 7s 160ms/step - loss: 0.5104 - accuracy: 0.8448 - val_loss: 0.2241 - val_accuracy: 0.9370
# Epoch 3/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.3245 - accuracy: 0.9057 - val_loss: 0.1511 - val_accuracy: 0.9652
# Epoch 4/30
# 44/44 [==============================] - 7s 165ms/step - loss: 0.2072 - accuracy: 0.9456 - val_loss: 0.0815 - val_accuracy: 0.9891
# Epoch 5/30
# 44/44 [==============================] - 7s 165ms/step - loss: 0.1135 - accuracy: 0.9761 - val_loss: 0.0552 - val_accuracy: 0.9870
# Epoch 6/30
# 44/44 [==============================] - 7s 166ms/step - loss: 0.0890 - accuracy: 0.9811 - val_loss: 0.0562 - val_accuracy: 0.9913
# Epoch 7/30
# 44/44 [==============================] - 7s 168ms/step - loss: 0.0823 - accuracy: 0.9819 - val_loss: 0.0994 - val_accuracy: 0.9630
# Epoch 8/30
# 44/44 [==============================] - 7s 166ms/step - loss: 0.0809 - accuracy: 0.9804 - val_loss: 0.0368 - val_accuracy: 0.9913
# Epoch 9/30
# 44/44 [==============================] - 8s 181ms/step - loss: 0.0413 - accuracy: 0.9935 - val_loss: 0.0443 - val_accuracy: 0.9891
# Epoch 10/30
# 44/44 [==============================] - 7s 162ms/step - loss: 0.0515 - accuracy: 0.9869 - val_loss: 0.0332 - val_accuracy: 0.9935
# Epoch 11/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.0514 - accuracy: 0.9862 - val_loss: 0.0588 - val_accuracy: 0.9848
# Epoch 12/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0422 - accuracy: 0.9913 - val_loss: 0.0220 - val_accuracy: 0.9913
# Epoch 13/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0220 - accuracy: 0.9971 - val_loss: 0.0169 - val_accuracy: 0.9978
# Epoch 14/30
# 44/44 [==============================] - 7s 165ms/step - loss: 0.0235 - accuracy: 0.9964 - val_loss: 0.0469 - val_accuracy: 0.9848
# Epoch 15/30
# 44/44 [==============================] - 7s 165ms/step - loss: 0.0889 - accuracy: 0.9739 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 16/30
# 44/44 [==============================] - 8s 183ms/step - loss: 0.0853 - accuracy: 0.9811 - val_loss: 0.0501 - val_accuracy: 0.9848
# Epoch 17/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0556 - accuracy: 0.9869 - val_loss: 0.0149 - val_accuracy: 0.9978
# Epoch 18/30
# 44/44 [==============================] - 7s 166ms/step - loss: 0.0345 - accuracy: 0.9935 - val_loss: 0.0156 - val_accuracy: 0.9978
# Epoch 19/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0366 - accuracy: 0.9935 - val_loss: 0.0101 - val_accuracy: 0.9978
# Epoch 20/30
# 44/44 [==============================] - 7s 165ms/step - loss: 0.0202 - accuracy: 0.9978 - val_loss: 0.0153 - val_accuracy: 0.9935
# Epoch 21/30
# 44/44 [==============================] - 8s 181ms/step - loss: 0.0242 - accuracy: 0.9956 - val_loss: 0.0112 - val_accuracy: 0.9978
# Epoch 22/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0266 - accuracy: 0.9920 - val_loss: 0.0165 - val_accuracy: 0.9978
# Epoch 23/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.0221 - accuracy: 0.9964 - val_loss: 0.0205 - val_accuracy: 0.9891
# Epoch 24/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.0366 - accuracy: 0.9891 - val_loss: 0.0251 - val_accuracy: 0.9935
# Epoch 25/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0242 - accuracy: 0.9956 - val_loss: 0.0110 - val_accuracy: 0.9978
# Epoch 26/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.0480 - accuracy: 0.9877 - val_loss: 0.0158 - val_accuracy: 0.9957
# Epoch 27/30
# 44/44 [==============================] - 7s 167ms/step - loss: 0.0803 - accuracy: 0.9739 - val_loss: 0.0176 - val_accuracy: 0.9913
# Epoch 28/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0524 - accuracy: 0.9855 - val_loss: 0.0194 - val_accuracy: 0.9957
# Epoch 29/30
# 44/44 [==============================] - 7s 166ms/step - loss: 0.0677 - accuracy: 0.9782 - val_loss: 0.0204 - val_accuracy: 0.9957
# Epoch 30/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.0621 - accuracy: 0.9833 - val_loss: 0.0112 - val_accuracy: 0.9978
# 15/15 [==============================] - 2s 116ms/step - loss: 0.0192 - accuracy: 0.9957
# Training ResNet50...
# Epoch 1/30
# 44/44 [==============================] - 16s 233ms/step - loss: 10.3509 - accuracy: 0.1690 - val_loss: 1.9404 - val_accuracy: 0.5087
# Epoch 2/30
# 44/44 [==============================] - 7s 162ms/step - loss: 2.2003 - accuracy: 0.3299 - val_loss: 1.5404 - val_accuracy: 0.5935
# Epoch 3/30
# 44/44 [==============================] - 7s 162ms/step - loss: 1.9153 - accuracy: 0.3822 - val_loss: 1.3502 - val_accuracy: 0.6543
# Epoch 4/30
# 44/44 [==============================] - 7s 166ms/step - loss: 1.7497 - accuracy: 0.4126 - val_loss: 1.1412 - val_accuracy: 0.7109
# Epoch 5/30
# 44/44 [==============================] - 7s 166ms/step - loss: 1.6495 - accuracy: 0.4474 - val_loss: 1.1269 - val_accuracy: 0.6783
# Epoch 6/30
# 44/44 [==============================] - 7s 164ms/step - loss: 1.5836 - accuracy: 0.4402 - val_loss: 0.8776 - val_accuracy: 0.8174
# Epoch 7/30
# 44/44 [==============================] - 7s 162ms/step - loss: 1.3821 - accuracy: 0.5062 - val_loss: 0.7224 - val_accuracy: 0.8391
# Epoch 8/30
# 44/44 [==============================] - 7s 165ms/step - loss: 1.3437 - accuracy: 0.5250 - val_loss: 0.8980 - val_accuracy: 0.7935
# Epoch 9/30
# 44/44 [==============================] - 7s 162ms/step - loss: 1.3808 - accuracy: 0.5134 - val_loss: 0.8276 - val_accuracy: 0.8370
# Epoch 10/30
# 44/44 [==============================] - 7s 165ms/step - loss: 1.5254 - accuracy: 0.4409 - val_loss: 0.7250 - val_accuracy: 0.7935
# Epoch 11/30
# 44/44 [==============================] - 7s 165ms/step - loss: 1.3833 - accuracy: 0.4859 - val_loss: 0.9207 - val_accuracy: 0.7130
# Epoch 12/30
# 44/44 [==============================] - 8s 184ms/step - loss: 1.5505 - accuracy: 0.4329 - val_loss: 0.7052 - val_accuracy: 0.8500
# Epoch 13/30
# 44/44 [==============================] - 7s 161ms/step - loss: 1.3460 - accuracy: 0.5033 - val_loss: 0.7154 - val_accuracy: 0.8261
# Epoch 14/30
# 44/44 [==============================] - 7s 166ms/step - loss: 1.3203 - accuracy: 0.5098 - val_loss: 0.5862 - val_accuracy: 0.8370
# Epoch 15/30
# 44/44 [==============================] - 8s 186ms/step - loss: 1.2443 - accuracy: 0.5366 - val_loss: 0.5401 - val_accuracy: 0.8978
# Epoch 16/30
# 44/44 [==============================] - 7s 161ms/step - loss: 1.2299 - accuracy: 0.5402 - val_loss: 0.5538 - val_accuracy: 0.8326
# Epoch 17/30
# 44/44 [==============================] - 7s 164ms/step - loss: 1.2732 - accuracy: 0.5236 - val_loss: 0.5136 - val_accuracy: 0.8717
# Epoch 18/30
# 44/44 [==============================] - 7s 162ms/step - loss: 1.1558 - accuracy: 0.5497 - val_loss: 0.4935 - val_accuracy: 0.8543
# Epoch 19/30
# 44/44 [==============================] - 7s 164ms/step - loss: 1.2095 - accuracy: 0.5402 - val_loss: 0.5194 - val_accuracy: 0.9130
# Epoch 20/30
# 44/44 [==============================] - 8s 184ms/step - loss: 1.1046 - accuracy: 0.5751 - val_loss: 0.4822 - val_accuracy: 0.8717
# Epoch 21/30
# 44/44 [==============================] - 7s 161ms/step - loss: 1.1947 - accuracy: 0.5395 - val_loss: 0.4974 - val_accuracy: 0.9152
# Epoch 22/30
# 44/44 [==============================] - 7s 165ms/step - loss: 1.1570 - accuracy: 0.5569 - val_loss: 0.4468 - val_accuracy: 0.8935
# Epoch 23/30
# 44/44 [==============================] - 7s 162ms/step - loss: 1.2398 - accuracy: 0.5170 - val_loss: 0.4457 - val_accuracy: 0.8870
# Epoch 24/30
# 44/44 [==============================] - 7s 163ms/step - loss: 1.0830 - accuracy: 0.5845 - val_loss: 0.5195 - val_accuracy: 0.8457
# Epoch 25/30
# 44/44 [==============================] - 7s 163ms/step - loss: 1.1309 - accuracy: 0.5700 - val_loss: 0.4480 - val_accuracy: 0.8891
# Epoch 26/30
# 44/44 [==============================] - 7s 161ms/step - loss: 1.0504 - accuracy: 0.5932 - val_loss: 0.3617 - val_accuracy: 0.9109
# Epoch 27/30
# 44/44 [==============================] - 7s 164ms/step - loss: 1.1294 - accuracy: 0.5555 - val_loss: 0.4030 - val_accuracy: 0.9130
# Epoch 28/30
# 44/44 [==============================] - 7s 163ms/step - loss: 1.1832 - accuracy: 0.5395 - val_loss: 0.3923 - val_accuracy: 0.9087
# Epoch 29/30
# 44/44 [==============================] - 7s 163ms/step - loss: 1.1516 - accuracy: 0.5424 - val_loss: 0.4912 - val_accuracy: 0.8457
# Epoch 30/30
# 44/44 [==============================] - 7s 165ms/step - loss: 1.2394 - accuracy: 0.5250 - val_loss: 0.4532 - val_accuracy: 0.8870
# 15/15 [==============================] - 2s 102ms/step - loss: 0.4558 - accuracy: 0.8848
# Training InceptionV3...
# Epoch 1/30
# 44/44 [==============================] - 17s 217ms/step - loss: 9.7271 - accuracy: 0.6273 - val_loss: 0.3910 - val_accuracy: 0.9478
# Epoch 2/30
# 44/44 [==============================] - 5s 113ms/step - loss: 0.6771 - accuracy: 0.9268 - val_loss: 0.1378 - val_accuracy: 0.9739
# Epoch 3/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.3875 - accuracy: 0.9413 - val_loss: 0.1673 - val_accuracy: 0.9717
# Epoch 4/30
# 44/44 [==============================] - 5s 114ms/step - loss: 0.3094 - accuracy: 0.9579 - val_loss: 0.2014 - val_accuracy: 0.9783
# Epoch 5/30
# 44/44 [==============================] - 5s 110ms/step - loss: 0.3658 - accuracy: 0.9485 - val_loss: 0.1325 - val_accuracy: 0.9783
# Epoch 6/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.4187 - accuracy: 0.9434 - val_loss: 0.0976 - val_accuracy: 0.9783
# Epoch 7/30
# 44/44 [==============================] - 5s 112ms/step - loss: 0.2810 - accuracy: 0.9572 - val_loss: 0.0895 - val_accuracy: 0.9891
# Epoch 8/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.1079 - accuracy: 0.9732 - val_loss: 0.1115 - val_accuracy: 0.9717
# Epoch 9/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.1117 - accuracy: 0.9739 - val_loss: 0.0911 - val_accuracy: 0.9891
# Epoch 10/30
# 44/44 [==============================] - 5s 111ms/step - loss: 0.0776 - accuracy: 0.9811 - val_loss: 0.0968 - val_accuracy: 0.9761
# Epoch 11/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.2111 - accuracy: 0.9652 - val_loss: 0.0784 - val_accuracy: 0.9870
# Epoch 12/30
# 44/44 [==============================] - 5s 114ms/step - loss: 0.1562 - accuracy: 0.9724 - val_loss: 0.0789 - val_accuracy: 0.9848
# Epoch 13/30
# 44/44 [==============================] - 5s 106ms/step - loss: 0.1736 - accuracy: 0.9695 - val_loss: 0.0672 - val_accuracy: 0.9870
# Epoch 14/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.2984 - accuracy: 0.9601 - val_loss: 0.3575 - val_accuracy: 0.9609
# Epoch 15/30
# 44/44 [==============================] - 5s 113ms/step - loss: 0.7051 - accuracy: 0.9376 - val_loss: 0.0620 - val_accuracy: 0.9913
# Epoch 16/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.4177 - accuracy: 0.9587 - val_loss: 0.1739 - val_accuracy: 0.9783
# Epoch 17/30
# 44/44 [==============================] - 5s 112ms/step - loss: 0.3686 - accuracy: 0.9536 - val_loss: 0.1159 - val_accuracy: 0.9891
# Epoch 18/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.8337 - accuracy: 0.9485 - val_loss: 0.2548 - val_accuracy: 0.9870
# Epoch 19/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.9069 - accuracy: 0.9376 - val_loss: 0.2078 - val_accuracy: 0.9761
# Epoch 20/30
# 44/44 [==============================] - 5s 113ms/step - loss: 0.4327 - accuracy: 0.9572 - val_loss: 0.1672 - val_accuracy: 0.9717
# Epoch 21/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.2144 - accuracy: 0.9695 - val_loss: 0.1326 - val_accuracy: 0.9935
# Epoch 22/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.2266 - accuracy: 0.9724 - val_loss: 0.1768 - val_accuracy: 0.9804
# Epoch 23/30
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1554 - accuracy: 0.9797 - val_loss: 0.0749 - val_accuracy: 0.9891
# Epoch 24/30
# 44/44 [==============================] - 5s 108ms/step - loss: 0.1238 - accuracy: 0.9833 - val_loss: 0.0989 - val_accuracy: 0.9891
# Epoch 25/30
# 44/44 [==============================] - 5s 111ms/step - loss: 0.1262 - accuracy: 0.9826 - val_loss: 0.0995 - val_accuracy: 0.9891
# Epoch 26/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.1447 - accuracy: 0.9804 - val_loss: 0.1274 - val_accuracy: 0.9891
# Epoch 27/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.1512 - accuracy: 0.9826 - val_loss: 0.1108 - val_accuracy: 0.9870
# Epoch 28/30
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1239 - accuracy: 0.9811 - val_loss: 0.1177 - val_accuracy: 0.9913
# Epoch 29/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.1962 - accuracy: 0.9855 - val_loss: 0.1127 - val_accuracy: 0.9935
# Epoch 30/30
# 44/44 [==============================] - 5s 107ms/step - loss: 0.1224 - accuracy: 0.9804 - val_loss: 0.0871 - val_accuracy: 0.9913
# 15/15 [==============================] - 1s 75ms/step - loss: 0.2017 - accuracy: 0.9870
# Training MobileNetV2...
# Epoch 1/30
# 44/44 [==============================] - 10s 129ms/step - loss: 13.7533 - accuracy: 0.6889 - val_loss: 0.6881 - val_accuracy: 0.9609
# Epoch 2/30
# 44/44 [==============================] - 4s 90ms/step - loss: 1.2836 - accuracy: 0.9275 - val_loss: 0.4445 - val_accuracy: 0.9848
# Epoch 3/30
# 44/44 [==============================] - 4s 79ms/step - loss: 1.0040 - accuracy: 0.9391 - val_loss: 0.2834 - val_accuracy: 0.9804
# Epoch 4/30
# 44/44 [==============================] - 3s 78ms/step - loss: 0.6301 - accuracy: 0.9601 - val_loss: 0.1188 - val_accuracy: 0.9891
# Epoch 5/30
# 44/44 [==============================] - 4s 95ms/step - loss: 0.6399 - accuracy: 0.9630 - val_loss: 0.0201 - val_accuracy: 0.9957
# Epoch 6/30
# 44/44 [==============================] - 4s 82ms/step - loss: 0.2665 - accuracy: 0.9761 - val_loss: 0.0440 - val_accuracy: 0.9935
# Epoch 7/30
# 44/44 [==============================] - 4s 79ms/step - loss: 0.1708 - accuracy: 0.9869 - val_loss: 0.0631 - val_accuracy: 0.9978
# Epoch 8/30
# 44/44 [==============================] - 4s 93ms/step - loss: 0.8638 - accuracy: 0.9550 - val_loss: 0.3293 - val_accuracy: 0.9870
# Epoch 9/30
# 44/44 [==============================] - 4s 81ms/step - loss: 0.9626 - accuracy: 0.9565 - val_loss: 0.1140 - val_accuracy: 0.9848
# Epoch 10/30
# 44/44 [==============================] - 4s 80ms/step - loss: 0.6421 - accuracy: 0.9623 - val_loss: 0.1233 - val_accuracy: 0.9935
# Epoch 11/30
# 44/44 [==============================] - 4s 81ms/step - loss: 0.7393 - accuracy: 0.9637 - val_loss: 0.1928 - val_accuracy: 0.9870
# Epoch 12/30
# 44/44 [==============================] - 4s 96ms/step - loss: 0.4464 - accuracy: 0.9753 - val_loss: 0.1556 - val_accuracy: 0.9935
# Epoch 13/30
# 44/44 [==============================] - 3s 78ms/step - loss: 0.2862 - accuracy: 0.9811 - val_loss: 0.0931 - val_accuracy: 0.9935
# Epoch 14/30
# 44/44 [==============================] - 3s 79ms/step - loss: 0.1349 - accuracy: 0.9891 - val_loss: 0.0800 - val_accuracy: 0.9935
# Epoch 15/30
# 44/44 [==============================] - 4s 95ms/step - loss: 0.1786 - accuracy: 0.9833 - val_loss: 0.1143 - val_accuracy: 0.9935
# Epoch 16/30
# 44/44 [==============================] - 3s 78ms/step - loss: 0.1437 - accuracy: 0.9920 - val_loss: 7.6799e-07 - val_accuracy: 1.0000
# Epoch 17/30
# 44/44 [==============================] - 3s 79ms/step - loss: 0.2078 - accuracy: 0.9855 - val_loss: 0.0777 - val_accuracy: 0.9935
# Epoch 18/30
# 44/44 [==============================] - 4s 90ms/step - loss: 0.2313 - accuracy: 0.9826 - val_loss: 0.1705 - val_accuracy: 0.9935
# Epoch 19/30
# 44/44 [==============================] - 4s 80ms/step - loss: 0.1714 - accuracy: 0.9877 - val_loss: 0.1755 - val_accuracy: 0.9891
# Epoch 20/30
# 44/44 [==============================] - 4s 80ms/step - loss: 0.2376 - accuracy: 0.9862 - val_loss: 0.1220 - val_accuracy: 0.9913
# Epoch 21/30
# 44/44 [==============================] - 4s 92ms/step - loss: 0.3831 - accuracy: 0.9797 - val_loss: 0.4564 - val_accuracy: 0.9783
# Epoch 22/30
# 44/44 [==============================] - 4s 85ms/step - loss: 0.2492 - accuracy: 0.9811 - val_loss: 0.1229 - val_accuracy: 0.9935
# Epoch 23/30
# 44/44 [==============================] - 4s 81ms/step - loss: 0.2999 - accuracy: 0.9826 - val_loss: 0.4771 - val_accuracy: 0.9870
# Epoch 24/30
# 44/44 [==============================] - 4s 92ms/step - loss: 0.4207 - accuracy: 0.9790 - val_loss: 0.1885 - val_accuracy: 0.9891
# Epoch 25/30
# 44/44 [==============================] - 4s 79ms/step - loss: 0.2862 - accuracy: 0.9826 - val_loss: 0.0900 - val_accuracy: 0.9913
# Epoch 26/30
# 44/44 [==============================] - 4s 80ms/step - loss: 0.2471 - accuracy: 0.9869 - val_loss: 0.0468 - val_accuracy: 0.9935
# Epoch 27/30
# 44/44 [==============================] - 4s 84ms/step - loss: 0.3124 - accuracy: 0.9877 - val_loss: 0.3086 - val_accuracy: 0.9913
# Epoch 28/30
# 44/44 [==============================] - 4s 92ms/step - loss: 0.3555 - accuracy: 0.9797 - val_loss: 0.3184 - val_accuracy: 0.9870
# Epoch 29/30
# 44/44 [==============================] - 4s 80ms/step - loss: 0.4828 - accuracy: 0.9804 - val_loss: 0.1065 - val_accuracy: 0.9957
# Epoch 30/30
# 44/44 [==============================] - 4s 91ms/step - loss: 0.3775 - accuracy: 0.9775 - val_loss: 0.1206 - val_accuracy: 0.9957
# 15/15 [==============================] - 1s 63ms/step - loss: 0.2147 - accuracy: 0.9870
# Training DenseNet121...
# Epoch 1/30
# 44/44 [==============================] - 24s 316ms/step - loss: 10.2837 - accuracy: 0.5751 - val_loss: 0.3758 - val_accuracy: 0.9283
# Epoch 2/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.5008 - accuracy: 0.8869 - val_loss: 0.0984 - val_accuracy: 0.9826
# Epoch 3/30
# 44/44 [==============================] - 7s 166ms/step - loss: 0.1654 - accuracy: 0.9587 - val_loss: 0.1130 - val_accuracy: 0.9804
# Epoch 4/30
# 44/44 [==============================] - 6s 137ms/step - loss: 0.1317 - accuracy: 0.9594 - val_loss: 0.0537 - val_accuracy: 0.9804
# Epoch 5/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.1040 - accuracy: 0.9739 - val_loss: 0.0391 - val_accuracy: 0.9848
# Epoch 6/30
# 44/44 [==============================] - 7s 163ms/step - loss: 0.1164 - accuracy: 0.9710 - val_loss: 0.0438 - val_accuracy: 0.9891
# Epoch 7/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.1526 - accuracy: 0.9550 - val_loss: 0.0792 - val_accuracy: 0.9848
# Epoch 8/30
# 44/44 [==============================] - 6s 135ms/step - loss: 0.2929 - accuracy: 0.9289 - val_loss: 0.0458 - val_accuracy: 0.9957
# Epoch 9/30
# 44/44 [==============================] - 6s 140ms/step - loss: 0.1804 - accuracy: 0.9558 - val_loss: 0.0289 - val_accuracy: 0.9891
# Epoch 10/30
# 44/44 [==============================] - 6s 135ms/step - loss: 0.1033 - accuracy: 0.9695 - val_loss: 0.0196 - val_accuracy: 0.9913
# Epoch 11/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.1014 - accuracy: 0.9739 - val_loss: 0.0790 - val_accuracy: 0.9826
# Epoch 12/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.0799 - accuracy: 0.9761 - val_loss: 0.0624 - val_accuracy: 0.9935
# Epoch 13/30
# 44/44 [==============================] - 7s 165ms/step - loss: 0.0840 - accuracy: 0.9775 - val_loss: 0.0205 - val_accuracy: 0.9935
# Epoch 14/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.0669 - accuracy: 0.9819 - val_loss: 0.0125 - val_accuracy: 0.9913
# Epoch 15/30
# 44/44 [==============================] - 6s 142ms/step - loss: 0.0507 - accuracy: 0.9848 - val_loss: 0.0157 - val_accuracy: 0.9935
# Epoch 16/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.0495 - accuracy: 0.9855 - val_loss: 0.0323 - val_accuracy: 0.9870
# Epoch 17/30
# 44/44 [==============================] - 6s 139ms/step - loss: 0.1313 - accuracy: 0.9688 - val_loss: 0.0939 - val_accuracy: 0.9826
# Epoch 18/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.0767 - accuracy: 0.9790 - val_loss: 0.0933 - val_accuracy: 0.9870
# Epoch 19/30
# 44/44 [==============================] - 6s 138ms/step - loss: 0.0728 - accuracy: 0.9811 - val_loss: 0.0343 - val_accuracy: 0.9913
# Epoch 20/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.1443 - accuracy: 0.9659 - val_loss: 0.0494 - val_accuracy: 0.9891
# Epoch 21/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.3840 - accuracy: 0.9246 - val_loss: 0.0516 - val_accuracy: 0.9870
# Epoch 22/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.2786 - accuracy: 0.9369 - val_loss: 0.0475 - val_accuracy: 0.9891
# Epoch 23/30
# 44/44 [==============================] - 6s 137ms/step - loss: 0.2729 - accuracy: 0.9347 - val_loss: 0.0576 - val_accuracy: 0.9848
# Epoch 24/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.1618 - accuracy: 0.9601 - val_loss: 0.0176 - val_accuracy: 0.9935
# Epoch 25/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.1783 - accuracy: 0.9623 - val_loss: 0.1152 - val_accuracy: 0.9761
# Epoch 26/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.1461 - accuracy: 0.9652 - val_loss: 0.0726 - val_accuracy: 0.9935
# Epoch 27/30
# 44/44 [==============================] - 6s 141ms/step - loss: 0.1486 - accuracy: 0.9645 - val_loss: 0.0937 - val_accuracy: 0.9826
# Epoch 28/30
# 44/44 [==============================] - 6s 136ms/step - loss: 0.1022 - accuracy: 0.9739 - val_loss: 0.0504 - val_accuracy: 0.9935
# Epoch 29/30
# 44/44 [==============================] - 6s 142ms/step - loss: 0.0768 - accuracy: 0.9804 - val_loss: 0.0456 - val_accuracy: 0.9935
# Epoch 30/30
# 44/44 [==============================] - 7s 164ms/step - loss: 0.1033 - accuracy: 0.9753 - val_loss: 0.0316 - val_accuracy: 0.9935
# 15/15 [==============================] - 1s 92ms/step - loss: 0.0224 - accuracy: 0.9935

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
