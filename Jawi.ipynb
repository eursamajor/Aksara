# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Jawi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2, VGG16, ResNet50, InceptionV3, DenseNet121
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/eursamajor/Aksara/raw/main/Jawi.zip'

zip_path = './Jawi.zip'
extract_path = './'

response = requests.get(url)
with open(zip_path, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

#utk store data yang udah didownload dan extract
dataset_dir = os.path.join(extract_path, 'Jawi')

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 1200 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'VGG16': VGG16(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'ResNet50': ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'InceptionV3': InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'MobileNetV2': MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3)),
    'DenseNet121': DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 1s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training VGG16...
# Epoch 1/30
# 38/38 [==============================] - 21s 269ms/step - loss: 3.8574 - accuracy: 0.2875 - val_loss: 0.9429 - val_accuracy: 0.7825
# Epoch 2/30
# 38/38 [==============================] - 6s 163ms/step - loss: 0.8884 - accuracy: 0.7367 - val_loss: 0.4187 - val_accuracy: 0.9000
# Epoch 3/30
# 38/38 [==============================] - 6s 164ms/step - loss: 0.5096 - accuracy: 0.8550 - val_loss: 0.3244 - val_accuracy: 0.9250
# Epoch 4/30
# 38/38 [==============================] - 6s 164ms/step - loss: 0.3362 - accuracy: 0.9075 - val_loss: 0.2266 - val_accuracy: 0.9425
# Epoch 5/30
# 38/38 [==============================] - 6s 167ms/step - loss: 0.2517 - accuracy: 0.9292 - val_loss: 0.1921 - val_accuracy: 0.9525
# Epoch 6/30
# 38/38 [==============================] - 6s 165ms/step - loss: 0.2073 - accuracy: 0.9350 - val_loss: 0.1686 - val_accuracy: 0.9525
# Epoch 7/30
# 38/38 [==============================] - 6s 166ms/step - loss: 0.1626 - accuracy: 0.9508 - val_loss: 0.1601 - val_accuracy: 0.9600
# Epoch 8/30
# 38/38 [==============================] - 6s 166ms/step - loss: 0.1302 - accuracy: 0.9692 - val_loss: 0.1708 - val_accuracy: 0.9575
# Epoch 9/30
# 38/38 [==============================] - 6s 168ms/step - loss: 0.1333 - accuracy: 0.9633 - val_loss: 0.1424 - val_accuracy: 0.9550
# Epoch 10/30
# 38/38 [==============================] - 6s 168ms/step - loss: 0.1129 - accuracy: 0.9750 - val_loss: 0.1352 - val_accuracy: 0.9575
# Epoch 11/30
# 38/38 [==============================] - 6s 170ms/step - loss: 0.0844 - accuracy: 0.9817 - val_loss: 0.1185 - val_accuracy: 0.9550
# Epoch 12/30
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0693 - accuracy: 0.9833 - val_loss: 0.1187 - val_accuracy: 0.9675
# Epoch 13/30
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0674 - accuracy: 0.9867 - val_loss: 0.1081 - val_accuracy: 0.9725
# Epoch 14/30
# 38/38 [==============================] - 6s 169ms/step - loss: 0.0580 - accuracy: 0.9908 - val_loss: 0.1290 - val_accuracy: 0.9550
# Epoch 15/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0583 - accuracy: 0.9867 - val_loss: 0.1142 - val_accuracy: 0.9700
# Epoch 16/30
# 38/38 [==============================] - 6s 170ms/step - loss: 0.0353 - accuracy: 0.9950 - val_loss: 0.1325 - val_accuracy: 0.9650
# Epoch 17/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0388 - accuracy: 0.9900 - val_loss: 0.1230 - val_accuracy: 0.9625
# Epoch 18/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0434 - accuracy: 0.9875 - val_loss: 0.0998 - val_accuracy: 0.9625
# Epoch 19/30
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0433 - accuracy: 0.9900 - val_loss: 0.1029 - val_accuracy: 0.9750
# Epoch 20/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0345 - accuracy: 0.9900 - val_loss: 0.1347 - val_accuracy: 0.9550
# Epoch 21/30
# 38/38 [==============================] - 7s 175ms/step - loss: 0.0436 - accuracy: 0.9933 - val_loss: 0.0743 - val_accuracy: 0.9750
# Epoch 22/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0544 - accuracy: 0.9842 - val_loss: 0.0902 - val_accuracy: 0.9700
# Epoch 23/30
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0400 - accuracy: 0.9908 - val_loss: 0.1234 - val_accuracy: 0.9700
# Epoch 24/30
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0480 - accuracy: 0.9850 - val_loss: 0.1189 - val_accuracy: 0.9675
# Epoch 25/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0425 - accuracy: 0.9900 - val_loss: 0.1141 - val_accuracy: 0.9600
# Epoch 26/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0424 - accuracy: 0.9900 - val_loss: 0.0860 - val_accuracy: 0.9775
# Epoch 27/30
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0265 - accuracy: 0.9958 - val_loss: 0.0885 - val_accuracy: 0.9775
# Epoch 28/30
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0273 - accuracy: 0.9933 - val_loss: 0.1078 - val_accuracy: 0.9725
# Epoch 29/30
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0295 - accuracy: 0.9933 - val_loss: 0.0904 - val_accuracy: 0.9750
# Epoch 30/30
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0451 - accuracy: 0.9900 - val_loss: 0.0851 - val_accuracy: 0.9750
# 13/13 [==============================] - 2s 123ms/step - loss: 0.1294 - accuracy: 0.9600
# Training ResNet50...
# Epoch 1/30
# 38/38 [==============================] - 14s 226ms/step - loss: 12.8100 - accuracy: 0.0417 - val_loss: 3.5501 - val_accuracy: 0.0575
# Epoch 2/30
# 38/38 [==============================] - 6s 164ms/step - loss: 3.6363 - accuracy: 0.0417 - val_loss: 3.6095 - val_accuracy: 0.0675
# Epoch 3/30
# 38/38 [==============================] - 6s 162ms/step - loss: 3.6000 - accuracy: 0.0375 - val_loss: 3.5747 - val_accuracy: 0.0600
# Epoch 4/30
# 38/38 [==============================] - 6s 163ms/step - loss: 3.5760 - accuracy: 0.0492 - val_loss: 3.4750 - val_accuracy: 0.0575
# Epoch 5/30
# 38/38 [==============================] - 6s 168ms/step - loss: 3.5110 - accuracy: 0.0383 - val_loss: 3.4218 - val_accuracy: 0.0575
# Epoch 6/30
# 38/38 [==============================] - 7s 196ms/step - loss: 3.5082 - accuracy: 0.0375 - val_loss: 3.4032 - val_accuracy: 0.0625
# Epoch 7/30
# 38/38 [==============================] - 6s 163ms/step - loss: 3.4678 - accuracy: 0.0367 - val_loss: 3.3606 - val_accuracy: 0.0875
# Epoch 8/30
# 38/38 [==============================] - 6s 168ms/step - loss: 3.4680 - accuracy: 0.0433 - val_loss: 3.2906 - val_accuracy: 0.1025
# Epoch 9/30
# 38/38 [==============================] - 6s 164ms/step - loss: 3.4364 - accuracy: 0.0392 - val_loss: 3.2496 - val_accuracy: 0.1075
# Epoch 10/30
# 38/38 [==============================] - 6s 165ms/step - loss: 3.3915 - accuracy: 0.0617 - val_loss: 3.2183 - val_accuracy: 0.1175
# Epoch 11/30
# 38/38 [==============================] - 6s 167ms/step - loss: 3.4071 - accuracy: 0.0433 - val_loss: 3.2135 - val_accuracy: 0.1075
# Epoch 12/30
# 38/38 [==============================] - 6s 163ms/step - loss: 3.3946 - accuracy: 0.0533 - val_loss: 3.1737 - val_accuracy: 0.1100
# Epoch 13/30
# 38/38 [==============================] - 6s 167ms/step - loss: 3.3822 - accuracy: 0.0567 - val_loss: 3.1715 - val_accuracy: 0.1200
# Epoch 14/30
# 38/38 [==============================] - 8s 198ms/step - loss: 3.4156 - accuracy: 0.0533 - val_loss: 3.1567 - val_accuracy: 0.1100
# Epoch 15/30
# 38/38 [==============================] - 6s 163ms/step - loss: 3.3386 - accuracy: 0.0508 - val_loss: 3.1397 - val_accuracy: 0.1100
# Epoch 16/30
# 38/38 [==============================] - 6s 167ms/step - loss: 3.4013 - accuracy: 0.0483 - val_loss: 3.1088 - val_accuracy: 0.0950
# Epoch 17/30
# 38/38 [==============================] - 6s 164ms/step - loss: 3.3643 - accuracy: 0.0525 - val_loss: 3.1339 - val_accuracy: 0.1225
# Epoch 18/30
# 38/38 [==============================] - 6s 168ms/step - loss: 3.3659 - accuracy: 0.0492 - val_loss: 3.1649 - val_accuracy: 0.1100
# Epoch 19/30
# 38/38 [==============================] - 6s 167ms/step - loss: 3.3581 - accuracy: 0.0533 - val_loss: 3.1241 - val_accuracy: 0.1250
# Epoch 20/30
# 38/38 [==============================] - 6s 164ms/step - loss: 3.3613 - accuracy: 0.0542 - val_loss: 3.1087 - val_accuracy: 0.1400
# Epoch 21/30
# 38/38 [==============================] - 6s 165ms/step - loss: 3.3464 - accuracy: 0.0525 - val_loss: 3.1216 - val_accuracy: 0.1250
# Epoch 22/30
# 38/38 [==============================] - 6s 165ms/step - loss: 3.3132 - accuracy: 0.0600 - val_loss: 3.0372 - val_accuracy: 0.1325
# Epoch 23/30
# 38/38 [==============================] - 6s 169ms/step - loss: 3.2763 - accuracy: 0.0667 - val_loss: 3.0606 - val_accuracy: 0.1300
# Epoch 24/30
# 38/38 [==============================] - 6s 165ms/step - loss: 3.3344 - accuracy: 0.0583 - val_loss: 2.9905 - val_accuracy: 0.1400
# Epoch 25/30
# 38/38 [==============================] - 6s 168ms/step - loss: 3.2889 - accuracy: 0.0533 - val_loss: 2.9619 - val_accuracy: 0.1250
# Epoch 26/30
# 38/38 [==============================] - 6s 165ms/step - loss: 3.3467 - accuracy: 0.0517 - val_loss: 3.0506 - val_accuracy: 0.1075
# Epoch 27/30
# 38/38 [==============================] - 6s 165ms/step - loss: 3.3526 - accuracy: 0.0492 - val_loss: 2.9451 - val_accuracy: 0.1275
# Epoch 28/30
# 38/38 [==============================] - 6s 164ms/step - loss: 3.2856 - accuracy: 0.0550 - val_loss: 2.9855 - val_accuracy: 0.1525
# Epoch 29/30
# 38/38 [==============================] - 6s 167ms/step - loss: 3.3063 - accuracy: 0.0517 - val_loss: 3.0653 - val_accuracy: 0.1375
# Epoch 30/30
# 38/38 [==============================] - 6s 164ms/step - loss: 3.3586 - accuracy: 0.0600 - val_loss: 3.0777 - val_accuracy: 0.1350
# 13/13 [==============================] - 1s 105ms/step - loss: 3.1055 - accuracy: 0.1225
# Training InceptionV3...
# Epoch 1/30
# 38/38 [==============================] - 16s 217ms/step - loss: 16.7139 - accuracy: 0.3642 - val_loss: 0.6483 - val_accuracy: 0.8125
# Epoch 2/30
# 38/38 [==============================] - 4s 108ms/step - loss: 1.0816 - accuracy: 0.6875 - val_loss: 0.5214 - val_accuracy: 0.8450
# Epoch 3/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.8053 - accuracy: 0.7750 - val_loss: 0.4760 - val_accuracy: 0.8575
# Epoch 4/30
# 38/38 [==============================] - 4s 115ms/step - loss: 0.6303 - accuracy: 0.8133 - val_loss: 0.4183 - val_accuracy: 0.8925
# Epoch 5/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.6003 - accuracy: 0.8450 - val_loss: 0.3720 - val_accuracy: 0.8900
# Epoch 6/30
# 38/38 [==============================] - 5s 119ms/step - loss: 0.4219 - accuracy: 0.8792 - val_loss: 0.2489 - val_accuracy: 0.9300
# Epoch 7/30
# 38/38 [==============================] - 4s 114ms/step - loss: 0.3217 - accuracy: 0.9008 - val_loss: 0.5969 - val_accuracy: 0.8725
# Epoch 8/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.4140 - accuracy: 0.8825 - val_loss: 0.3501 - val_accuracy: 0.9100
# Epoch 9/30
# 38/38 [==============================] - 4s 112ms/step - loss: 0.3558 - accuracy: 0.9008 - val_loss: 0.3643 - val_accuracy: 0.8925
# Epoch 10/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.4490 - accuracy: 0.8792 - val_loss: 0.3543 - val_accuracy: 0.9000
# Epoch 11/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.3471 - accuracy: 0.9025 - val_loss: 0.3261 - val_accuracy: 0.9200
# Epoch 12/30
# 38/38 [==============================] - 4s 116ms/step - loss: 0.3211 - accuracy: 0.9083 - val_loss: 0.3057 - val_accuracy: 0.9225
# Epoch 13/30
# 38/38 [==============================] - 4s 111ms/step - loss: 0.3383 - accuracy: 0.9100 - val_loss: 0.3731 - val_accuracy: 0.9100
# Epoch 14/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.3928 - accuracy: 0.8825 - val_loss: 0.4135 - val_accuracy: 0.8950
# Epoch 15/30
# 38/38 [==============================] - 4s 117ms/step - loss: 0.3230 - accuracy: 0.9083 - val_loss: 0.2614 - val_accuracy: 0.9350
# Epoch 16/30
# 38/38 [==============================] - 4s 110ms/step - loss: 0.2776 - accuracy: 0.9167 - val_loss: 0.3414 - val_accuracy: 0.9300
# Epoch 17/30
# 38/38 [==============================] - 4s 118ms/step - loss: 0.2325 - accuracy: 0.9267 - val_loss: 0.3997 - val_accuracy: 0.9175
# Epoch 18/30
# 38/38 [==============================] - 4s 112ms/step - loss: 0.3075 - accuracy: 0.9108 - val_loss: 0.3074 - val_accuracy: 0.9350
# Epoch 19/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.2760 - accuracy: 0.9225 - val_loss: 0.3520 - val_accuracy: 0.9200
# Epoch 20/30
# 38/38 [==============================] - 5s 120ms/step - loss: 0.2808 - accuracy: 0.9208 - val_loss: 0.3095 - val_accuracy: 0.9275
# Epoch 21/30
# 38/38 [==============================] - 4s 110ms/step - loss: 0.2867 - accuracy: 0.9175 - val_loss: 0.2529 - val_accuracy: 0.9225
# Epoch 22/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.2290 - accuracy: 0.9292 - val_loss: 0.3986 - val_accuracy: 0.9200
# Epoch 23/30
# 38/38 [==============================] - 4s 116ms/step - loss: 0.2774 - accuracy: 0.9208 - val_loss: 0.3768 - val_accuracy: 0.9175
# Epoch 24/30
# 38/38 [==============================] - 4s 110ms/step - loss: 0.2866 - accuracy: 0.9192 - val_loss: 0.3916 - val_accuracy: 0.9150
# Epoch 25/30
# 38/38 [==============================] - 5s 120ms/step - loss: 0.2464 - accuracy: 0.9292 - val_loss: 0.3371 - val_accuracy: 0.9350
# Epoch 26/30
# 38/38 [==============================] - 4s 114ms/step - loss: 0.2315 - accuracy: 0.9217 - val_loss: 0.3844 - val_accuracy: 0.9175
# Epoch 27/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.2826 - accuracy: 0.9225 - val_loss: 0.5790 - val_accuracy: 0.8925
# Epoch 28/30
# 38/38 [==============================] - 5s 120ms/step - loss: 0.2599 - accuracy: 0.9183 - val_loss: 0.3643 - val_accuracy: 0.9275
# Epoch 29/30
# 38/38 [==============================] - 4s 112ms/step - loss: 0.1935 - accuracy: 0.9367 - val_loss: 0.3987 - val_accuracy: 0.9075
# Epoch 30/30
# 38/38 [==============================] - 4s 109ms/step - loss: 0.2143 - accuracy: 0.9333 - val_loss: 0.3926 - val_accuracy: 0.9200
# 13/13 [==============================] - 1s 74ms/step - loss: 0.5994 - accuracy: 0.8800
# Training MobileNetV2...
# Epoch 1/30
# 38/38 [==============================] - 9s 123ms/step - loss: 16.8693 - accuracy: 0.4792 - val_loss: 1.2610 - val_accuracy: 0.8150
# Epoch 2/30
# 38/38 [==============================] - 3s 81ms/step - loss: 1.0219 - accuracy: 0.8483 - val_loss: 0.5014 - val_accuracy: 0.9225
# Epoch 3/30
# 38/38 [==============================] - 3s 80ms/step - loss: 0.7638 - accuracy: 0.8783 - val_loss: 0.6654 - val_accuracy: 0.9050
# Epoch 4/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.5903 - accuracy: 0.9017 - val_loss: 0.5723 - val_accuracy: 0.9225
# Epoch 5/30
# 38/38 [==============================] - 3s 89ms/step - loss: 0.6252 - accuracy: 0.8950 - val_loss: 0.7222 - val_accuracy: 0.8900
# Epoch 6/30
# 38/38 [==============================] - 3s 80ms/step - loss: 0.5687 - accuracy: 0.9067 - val_loss: 0.5825 - val_accuracy: 0.8950
# Epoch 7/30
# 38/38 [==============================] - 3s 76ms/step - loss: 0.4142 - accuracy: 0.9267 - val_loss: 0.4046 - val_accuracy: 0.9450
# Epoch 8/30
# 38/38 [==============================] - 3s 77ms/step - loss: 0.5217 - accuracy: 0.9183 - val_loss: 0.5851 - val_accuracy: 0.9225
# Epoch 9/30
# 38/38 [==============================] - 4s 99ms/step - loss: 0.4297 - accuracy: 0.9300 - val_loss: 0.4678 - val_accuracy: 0.9275
# Epoch 10/30
# 38/38 [==============================] - 3s 79ms/step - loss: 0.2650 - accuracy: 0.9492 - val_loss: 0.7912 - val_accuracy: 0.9150
# Epoch 11/30
# 38/38 [==============================] - 3s 77ms/step - loss: 0.5176 - accuracy: 0.9358 - val_loss: 0.5407 - val_accuracy: 0.9300
# Epoch 12/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.6462 - accuracy: 0.9175 - val_loss: 0.6540 - val_accuracy: 0.9250
# Epoch 13/30
# 38/38 [==============================] - 3s 79ms/step - loss: 0.7142 - accuracy: 0.9025 - val_loss: 0.8224 - val_accuracy: 0.9200
# Epoch 14/30
# 38/38 [==============================] - 3s 80ms/step - loss: 0.4771 - accuracy: 0.9258 - val_loss: 0.7600 - val_accuracy: 0.9100
# Epoch 15/30
# 38/38 [==============================] - 3s 81ms/step - loss: 0.3798 - accuracy: 0.9408 - val_loss: 0.4756 - val_accuracy: 0.9250
# Epoch 16/30
# 38/38 [==============================] - 3s 79ms/step - loss: 0.2562 - accuracy: 0.9458 - val_loss: 0.4094 - val_accuracy: 0.9225
# Epoch 17/30
# 38/38 [==============================] - 3s 90ms/step - loss: 0.2761 - accuracy: 0.9525 - val_loss: 0.4162 - val_accuracy: 0.9350
# Epoch 18/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.2563 - accuracy: 0.9558 - val_loss: 0.6940 - val_accuracy: 0.9250
# Epoch 19/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.1660 - accuracy: 0.9667 - val_loss: 0.5304 - val_accuracy: 0.9325
# Epoch 20/30
# 38/38 [==============================] - 3s 82ms/step - loss: 0.2486 - accuracy: 0.9583 - val_loss: 0.7486 - val_accuracy: 0.9250
# Epoch 21/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.3468 - accuracy: 0.9550 - val_loss: 0.8233 - val_accuracy: 0.9125
# Epoch 22/30
# 38/38 [==============================] - 3s 80ms/step - loss: 0.2509 - accuracy: 0.9567 - val_loss: 0.8023 - val_accuracy: 0.9325
# Epoch 23/30
# 38/38 [==============================] - 4s 92ms/step - loss: 0.3527 - accuracy: 0.9492 - val_loss: 1.0117 - val_accuracy: 0.9275
# Epoch 24/30
# 38/38 [==============================] - 3s 77ms/step - loss: 0.4368 - accuracy: 0.9408 - val_loss: 0.6646 - val_accuracy: 0.9250
# Epoch 25/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.2890 - accuracy: 0.9525 - val_loss: 0.7074 - val_accuracy: 0.9375
# Epoch 26/30
# 38/38 [==============================] - 4s 105ms/step - loss: 0.6707 - accuracy: 0.9317 - val_loss: 0.6389 - val_accuracy: 0.9350
# Epoch 27/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.5647 - accuracy: 0.9317 - val_loss: 0.6680 - val_accuracy: 0.9250
# Epoch 28/30
# 38/38 [==============================] - 3s 78ms/step - loss: 0.5494 - accuracy: 0.9458 - val_loss: 0.8438 - val_accuracy: 0.9125
# Epoch 29/30
# 38/38 [==============================] - 4s 100ms/step - loss: 0.5905 - accuracy: 0.9300 - val_loss: 1.0527 - val_accuracy: 0.9250
# Epoch 30/30
# 38/38 [==============================] - 3s 79ms/step - loss: 0.7261 - accuracy: 0.9400 - val_loss: 1.1190 - val_accuracy: 0.9150
# 13/13 [==============================] - 1s 48ms/step - loss: 1.2269 - accuracy: 0.9075
# Training DenseNet121...
# Epoch 1/30
# 38/38 [==============================] - 21s 281ms/step - loss: 10.5326 - accuracy: 0.3792 - val_loss: 0.5810 - val_accuracy: 0.8375
# Epoch 2/30
# 38/38 [==============================] - 5s 142ms/step - loss: 0.7754 - accuracy: 0.7775 - val_loss: 0.3266 - val_accuracy: 0.8850
# Epoch 3/30
# 38/38 [==============================] - 6s 146ms/step - loss: 0.4658 - accuracy: 0.8608 - val_loss: 0.3458 - val_accuracy: 0.9050
# Epoch 4/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.4124 - accuracy: 0.8783 - val_loss: 0.2329 - val_accuracy: 0.9350
# Epoch 5/30
# 38/38 [==============================] - 6s 147ms/step - loss: 0.2935 - accuracy: 0.9142 - val_loss: 0.2294 - val_accuracy: 0.9275
# Epoch 6/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2337 - accuracy: 0.9267 - val_loss: 0.2420 - val_accuracy: 0.9225
# Epoch 7/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.1989 - accuracy: 0.9333 - val_loss: 0.1701 - val_accuracy: 0.9550
# Epoch 8/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.1712 - accuracy: 0.9392 - val_loss: 0.2116 - val_accuracy: 0.9450
# Epoch 9/30
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1828 - accuracy: 0.9425 - val_loss: 0.3209 - val_accuracy: 0.9000
# Epoch 10/30
# 38/38 [==============================] - 6s 146ms/step - loss: 0.2416 - accuracy: 0.9250 - val_loss: 0.2413 - val_accuracy: 0.9375
# Epoch 11/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1560 - accuracy: 0.9525 - val_loss: 0.1869 - val_accuracy: 0.9475
# Epoch 12/30
# 38/38 [==============================] - 6s 148ms/step - loss: 0.1383 - accuracy: 0.9542 - val_loss: 0.2473 - val_accuracy: 0.9425
# Epoch 13/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1899 - accuracy: 0.9442 - val_loss: 0.2255 - val_accuracy: 0.9325
# Epoch 14/30
# 38/38 [==============================] - 6s 148ms/step - loss: 0.1802 - accuracy: 0.9475 - val_loss: 0.2286 - val_accuracy: 0.9400
# Epoch 15/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1272 - accuracy: 0.9617 - val_loss: 0.1611 - val_accuracy: 0.9550
# Epoch 16/30
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0990 - accuracy: 0.9667 - val_loss: 0.1956 - val_accuracy: 0.9500
# Epoch 17/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.1407 - accuracy: 0.9483 - val_loss: 0.2560 - val_accuracy: 0.9425
# Epoch 18/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2520 - accuracy: 0.9258 - val_loss: 0.2660 - val_accuracy: 0.9300
# Epoch 19/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.2141 - accuracy: 0.9367 - val_loss: 0.2282 - val_accuracy: 0.9450
# Epoch 20/30
# 38/38 [==============================] - 6s 149ms/step - loss: 0.1900 - accuracy: 0.9467 - val_loss: 0.2932 - val_accuracy: 0.9225
# Epoch 21/30
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1929 - accuracy: 0.9408 - val_loss: 0.2428 - val_accuracy: 0.9250
# Epoch 22/30
# 38/38 [==============================] - 6s 148ms/step - loss: 0.1685 - accuracy: 0.9533 - val_loss: 0.1818 - val_accuracy: 0.9500
# Epoch 23/30
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1863 - accuracy: 0.9483 - val_loss: 0.2785 - val_accuracy: 0.9575
# Epoch 24/30
# 38/38 [==============================] - 6s 146ms/step - loss: 0.2636 - accuracy: 0.9417 - val_loss: 0.1810 - val_accuracy: 0.9600
# Epoch 25/30
# 38/38 [==============================] - 6s 145ms/step - loss: 0.2077 - accuracy: 0.9375 - val_loss: 0.3204 - val_accuracy: 0.9375
# Epoch 26/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.2470 - accuracy: 0.9308 - val_loss: 0.2055 - val_accuracy: 0.9525
# Epoch 27/30
# 38/38 [==============================] - 6s 151ms/step - loss: 0.1747 - accuracy: 0.9475 - val_loss: 0.1911 - val_accuracy: 0.9450
# Epoch 28/30
# 38/38 [==============================] - 5s 143ms/step - loss: 0.1279 - accuracy: 0.9642 - val_loss: 0.2034 - val_accuracy: 0.9525
# Epoch 29/30
# 38/38 [==============================] - 6s 149ms/step - loss: 0.1479 - accuracy: 0.9592 - val_loss: 0.2676 - val_accuracy: 0.9575
# Epoch 30/30
# 38/38 [==============================] - 5s 144ms/step - loss: 0.1120 - accuracy: 0.9642 - val_loss: 0.2497 - val_accuracy: 0.9525
# 13/13 [==============================] - 1s 97ms/step - loss: 0.2173 - accuracy: 0.9450

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
