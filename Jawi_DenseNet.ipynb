# %% [markdown]
# <a href="https://colab.research.google.com/github/eursamajor/Aksara/blob/main/Jawi_DenseNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT DATA AND DATA AUGMENTATION

# %%
import os
import shutil
import requests
import zipfile
from io import BytesIO
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet169, DenseNet201
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/eursamajor/Aksara/raw/main/Jawi.zip'

zip_path = './Jawi.zip'
extract_path = './'

response = requests.get(url)
with open(zip_path, 'wb') as f:
    f.write(response.content)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

#utk store data yang udah didownload dan extract
dataset_dir = os.path.join(extract_path, 'Jawi')

# new dir utk taroh 3 data
base_dir = './dataset_split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)
    for class_name in os.listdir(dataset_dir):
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# split data
for class_name in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_path)

    train_images, temp_images = train_test_split(images, test_size=0.4, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name, image))

    for image in val_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(val_dir, class_name, image))

    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name, image))

#augment
img_size = (224, 224)
batch_size = 32

# train_datagen = ImageDataGenerator(rescale=1./255,
#                                    rotation_range=40,
#                                    shear_range=0.2,
#                                    zoom_range=0.2,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2,
#                                    horizontal_flip=True,
#                                    fill_mode='nearest'
#                                    )
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
# Out:
# Found 1200 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.

# %% [markdown]
# ### DEFINE MODEL

# %%
def create_model(base_model):
    for layer in base_model.layers:
        layer.trainable = False

    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

models = {
    'DenseNet169': DenseNet169(weights='imagenet', include_top=False, input_shape=(224, 224,3)),
    'DenseNet201': DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
}

results = {}
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# ### TRAIN AND EVALUATION

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

for model_name, base_model in models.items():
    print(f"Training {model_name}...")
    model = create_model(base_model)
    history = model.fit(train_generator, validation_data=val_generator, epochs=30)

    test_loss, test_acc = model.evaluate(test_generator)
    results[model_name] = {
        'accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy'],
        'test_accuracy': test_acc
    }
# Out:
# Training DenseNet169...
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.2860 - loss: 22.4594 - val_accuracy: 0.7375 - val_loss: 3.3930
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.8683 - loss: 1.0666 - val_accuracy: 0.8800 - val_loss: 0.8761
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9530 - loss: 0.2265 - val_accuracy: 0.8925 - val_loss: 0.8123
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.9529 - loss: 0.2347 - val_accuracy: 0.9050 - val_loss: 0.6021
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9524 - loss: 0.3104 - val_accuracy: 0.9050 - val_loss: 0.8182
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.9453 - loss: 0.3685 - val_accuracy: 0.9050 - val_loss: 0.5622
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - accuracy: 0.9789 - loss: 0.1336 - val_accuracy: 0.9125 - val_loss: 0.6857
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9811 - loss: 0.1128 - val_accuracy: 0.9350 - val_loss: 0.4213
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9829 - loss: 0.1100 - val_accuracy: 0.9350 - val_loss: 0.4420
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9877 - loss: 0.0708 - val_accuracy: 0.9275 - val_loss: 0.3816
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 0.9881 - loss: 0.0562 - val_accuracy: 0.9175 - val_loss: 0.7513
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.9779 - loss: 0.1539 - val_accuracy: 0.8800 - val_loss: 0.9572
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9660 - loss: 0.2106 - val_accuracy: 0.9050 - val_loss: 0.6321
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.9746 - loss: 0.1492 - val_accuracy: 0.9025 - val_loss: 0.9036
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.9835 - loss: 0.1012 - val_accuracy: 0.9275 - val_loss: 0.5552
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9598 - loss: 0.2609 - val_accuracy: 0.8250 - val_loss: 2.0907
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.9704 - loss: 0.2271 - val_accuracy: 0.9400 - val_loss: 0.3881
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.9834 - loss: 0.0987 - val_accuracy: 0.9225 - val_loss: 0.8161
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.9824 - loss: 0.1526 - val_accuracy: 0.9200 - val_loss: 0.6791
# Epoch 20/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.9856 - loss: 0.0507 - val_accuracy: 0.9150 - val_loss: 0.9906
# Epoch 21/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9804 - loss: 0.1548 - val_accuracy: 0.8925 - val_loss: 1.1503
# Epoch 22/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.9738 - loss: 0.1745 - val_accuracy: 0.8950 - val_loss: 1.1799
# Epoch 23/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.9761 - loss: 0.2134 - val_accuracy: 0.9100 - val_loss: 0.9099
# Epoch 24/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.9824 - loss: 0.1659 - val_accuracy: 0.8975 - val_loss: 1.4224
# Epoch 25/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.9679 - loss: 0.2292 - val_accuracy: 0.9200 - val_loss: 0.7425
# Epoch 26/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 0.9818 - loss: 0.0988 - val_accuracy: 0.9225 - val_loss: 0.9036
# Epoch 27/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.9691 - loss: 0.2162 - val_accuracy: 0.9150 - val_loss: 0.7836
# Epoch 28/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9839 - loss: 0.0948 - val_accuracy: 0.9125 - val_loss: 0.8727
# Epoch 29/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.9897 - loss: 0.1438 - val_accuracy: 0.9225 - val_loss: 0.6256
# Epoch 30/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 0.9918 - loss: 0.0334 - val_accuracy: 0.9325 - val_loss: 0.4856
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9350 - loss: 0.5513
# Training DenseNet201...
# Epoch 1/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.2962 - loss: 24.2603 - val_accuracy: 0.8550 - val_loss: 1.0296
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - accuracy: 0.8969 - loss: 0.7228 - val_accuracy: 0.9075 - val_loss: 0.4112
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.9650 - loss: 0.1340 - val_accuracy: 0.9325 - val_loss: 0.3616
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.9777 - loss: 0.0957 - val_accuracy: 0.9200 - val_loss: 0.3263
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9738 - loss: 0.0847 - val_accuracy: 0.9525 - val_loss: 0.2400
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - accuracy: 0.9858 - loss: 0.0740 - val_accuracy: 0.9050 - val_loss: 0.3747
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9839 - loss: 0.0568 - val_accuracy: 0.9325 - val_loss: 0.2790
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9880 - loss: 0.0417 - val_accuracy: 0.9300 - val_loss: 0.3389
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 187ms/step - accuracy: 0.9876 - loss: 0.0477 - val_accuracy: 0.9175 - val_loss: 0.4198
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.9922 - loss: 0.0456 - val_accuracy: 0.9375 - val_loss: 0.2312
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9799 - loss: 0.0956 - val_accuracy: 0.9125 - val_loss: 0.6406
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9760 - loss: 0.0981 - val_accuracy: 0.9225 - val_loss: 0.4557
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - accuracy: 0.9599 - loss: 0.2313 - val_accuracy: 0.9200 - val_loss: 0.5341
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.9597 - loss: 0.2495 - val_accuracy: 0.9250 - val_loss: 0.3954
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - accuracy: 0.9765 - loss: 0.0973 - val_accuracy: 0.8925 - val_loss: 0.8892
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - accuracy: 0.9326 - loss: 0.4908 - val_accuracy: 0.8525 - val_loss: 1.5466
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9556 - loss: 0.2953 - val_accuracy: 0.9150 - val_loss: 0.5145
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9753 - loss: 0.1673 - val_accuracy: 0.9075 - val_loss: 1.0251
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - accuracy: 0.9772 - loss: 0.1572 - val_accuracy: 0.9525 - val_loss: 0.3493
# Epoch 20/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.9820 - loss: 0.1114 - val_accuracy: 0.9325 - val_loss: 0.6725
# Epoch 21/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9883 - loss: 0.0659 - val_accuracy: 0.9200 - val_loss: 0.4036
# Epoch 22/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9768 - loss: 0.1070 - val_accuracy: 0.9375 - val_loss: 0.4599
# Epoch 23/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9960 - loss: 0.0253 - val_accuracy: 0.9375 - val_loss: 0.3390
# Epoch 24/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.9890 - loss: 0.0865 - val_accuracy: 0.9250 - val_loss: 0.7175
# Epoch 25/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.9839 - loss: 0.0812 - val_accuracy: 0.9300 - val_loss: 0.6168
# Epoch 26/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9881 - loss: 0.0616 - val_accuracy: 0.9225 - val_loss: 0.7118
# Epoch 27/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9896 - loss: 0.0777 - val_accuracy: 0.9250 - val_loss: 0.4313
# Epoch 28/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9935 - loss: 0.0320 - val_accuracy: 0.9350 - val_loss: 0.4805
# Epoch 29/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 187ms/step - accuracy: 0.9911 - loss: 0.1190 - val_accuracy: 0.9300 - val_loss: 0.7600
# Epoch 30/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 207ms/step - accuracy: 0.9861 - loss: 0.0326 - val_accuracy: 0.9225 - val_loss: 0.6758
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.9376 - loss: 0.7638

# %%
# Plotting Training Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['accuracy'], label=f"{model_name} Train")
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.title('Training Accuracy Comparison')
plt.grid(False)
plt.show()

# Plotting Validation Accuracy
plt.figure(figsize=(14, 8))
for model_name, result in results.items():
    plt.plot(result['val_accuracy'], label=f"{model_name} Validation")
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.title('Validation Accuracy Comparison')
plt.grid(False)
plt.show()
